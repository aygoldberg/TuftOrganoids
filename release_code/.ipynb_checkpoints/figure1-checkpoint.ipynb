# %%
getwd()
# Out:
# [1] "/hpc/hub_oudenaarden/agiladi/data/tuft/release_code"

# %% [markdown]
# #dim(tuft_umis)
# #us = tuft_umis[ rowSums(tuft_umis) > 0,]
# shuffle_umis_matrix = function(us) {
#     rs = rowSums(us); cs = colSums(us)
#     genes = names(rs)
#     rs_vec = rep(genes, rs); length(rs_vec)
#     sh_us = NULL
#     for (i in names(cs)) {
#         idx = sample(length(rs_vec), cs[i])
#         sh_us = cbind(sh_us,
#                      table(factor(rs_vec[idx], levels = genes)))
#         rs_vec = rs_vec[-idx]
#     }
#     sh_us = as.matrix(sh_us)
#     colnames(sh_us) = names(cs)
#     sh_us
# }
#
# #sh_us = shuffle_umis_matrix(us)

# %%
setwd("..")

# %%
set.seed(1111)

library(metacell)
source("scripts/metacell_functions.r")
library("Seurat")
library(flowCore)
library(flowWorkspace)
library(RColorBrewer)
library(GEOquery)
library(scales)
library(Hmisc)
# Out:
# Loading required package: reshape2
# Warning message:
# “package ‘reshape2’ was built under R version 3.6.3”Loading required package: plyr
# Loading required package: plotrix
# Warning message in .getGeneric(f, where, package):
# “input string 'unable to find an inherited method for function ‘spillover’ for signature.*(flowSet|ncdfFlowSet)' cannot be translated to UTF-8, is it valid in 'ANSI_X3.4-1968'?”Warning message in .getGeneric(f, where, package):
# “input string 'unable to find an inherited method for function ‘spillover’ for signature.*(flowSet|ncdfFlowSet)' cannot be translated to UTF-8, is it valid in 'ANSI_X3.4-1968'?”Warning message in .getGeneric(f, where, package):
# “input string 'unable to find an inherited method for function ‘spillover’ for signature.*(flowSet|ncdfFlowSet)' cannot be translated to UTF-8, is it valid in 'ANSI_X3.4-1968'?”Loading required package: Biobase
# Loading required package: BiocGenerics
# Loading required package: parallel
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
# The following object is masked from ‘package:flowCore’:
#
#     normalize
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which, which.max, which.min
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
# Setting options('download.file.method.GEOquery'='auto')
# Setting options('GEOquery.inmemory.gpl'=FALSE)
# Warning message:
# “package ‘scales’ was built under R version 3.6.3”
# Attaching package: ‘scales’
#
# The following object is masked from ‘package:plotrix’:
#
#     rescale
#
# Warning message:
# “package ‘Hmisc’ was built under R version 3.6.3”Loading required package: lattice
# Warning message:
# “package ‘lattice’ was built under R version 3.6.3”Loading required package: survival
# Warning message:
# “package ‘survival’ was built under R version 3.6.3”Loading required package: Formula
# Warning message:
# “package ‘Formula’ was built under R version 3.6.3”Loading required package: ggplot2
# Warning message:
# “package ‘ggplot2’ was built under R version 3.6.3”
# Attaching package: ‘Hmisc’
#
# The following object is masked from ‘package:Biobase’:
#
#     contents
#
# The following object is masked from ‘package:Seurat’:
#
#     Key
#
# The following objects are masked from ‘package:plyr’:
#
#     is.discrete, summarize
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units

# %%
outdir = "release_figures/primary_material/"
dir.create(outdir)
# Out:
# Warning message in dir.create(outdir):
# “'release_figures/primary_material' already exists”

# %% [markdown]
# ## Read Elmentaite's dataset

# %%
obj = readRDS("published_data/Naturedataset.RDS")

# %%
X = obj@assays$RNA
metadata = obj@meta.data

dim(X)
# Out:
# Loading required package: SeuratObject
# Warning message:
# “package ‘SeuratObject’ was built under R version 3.6.3”Registered S3 methods overwritten by 'SeuratObject':
#   method                     from
#   $.JackStrawData            Seurat
#   $.Seurat                   Seurat
#   $.SeuratCommand            Seurat
#   $<-.Seurat                 Seurat
#   [.Assay                    Seurat
#   [.DimReduc                 Seurat
#   [.Seurat                   Seurat
#   [.SeuratCommand            Seurat
#   [[.Assay                   Seurat
#   [[.DimReduc                Seurat
#   [[.Seurat                  Seurat
#   levels<-.Seurat            Seurat
#   .DollarNames.JackStrawData Seurat
#   .DollarNames.Seurat        Seurat
#   .DollarNames.SeuratCommand Seurat
#   as.list.SeuratCommand      Seurat
#   as.logical.JackStrawData   Seurat
#   dim.Assay                  Seurat
#   dim.DimReduc               Seurat
#   dim.Seurat                 Seurat
#   dimnames.Assay             Seurat
#   dimnames.DimReduc          Seurat
#   dimnames.Seurat            Seurat
#   droplevels.Seurat          Seurat
#   length.DimReduc            Seurat
#   levels.Seurat              Seurat
#   merge.Assay                Seurat
#   merge.Seurat               Seurat
#   names.DimReduc             Seurat
#   names.Seurat               Seurat
#   print.DimReduc             Seurat
#   subset.Assay               Seurat
#   subset.DimReduc            Seurat
#   subset.Seurat              Seurat
#
# Attaching package: ‘SeuratObject’
#
# The following object is masked from ‘package:Hmisc’:
#
#     Key
#
# The following objects are masked from ‘package:Seurat’:
#
#     AddMetaData, as.Graph, as.Seurat, as.sparse, Cells, Command,
#     CreateAssayObject, CreateDimReducObject, CreateSeuratObject,
#     DefaultAssay, DefaultAssay<-, Embeddings, FetchData, GetAssayData,
#     HVFInfo, Idents, Idents<-, JS, JS<-, Key, Key<-, Loadings,
#     Loadings<-, LogSeuratCommand, Misc, Misc<-, pbmc_small, Project,
#     Project<-, RenameCells, RenameIdents, ReorderIdent, SetAssayData,
#     SetIdent, StashIdent, Stdev, Tool, Tool<-, UpdateSeuratObject,
#     VariableFeatures, VariableFeatures<-, WhichCells
# [1]  33538 142113

# %% [markdown]
# head(metadata)
# table(metadata$Age_group)
#
# table(metadata$Diagnosis)

# %% [markdown]
# write.table(colnames(metadata))

# %% [markdown]
# Z = Seurat::ReadH5AD("published_data//epi_log_counts02_v2.h5ad")

# %% [markdown]
# table(metadata$Diagnosis, metadata$Age_group)

# %% [markdown]
# table(metadata$annotation)
#
# table(metadata$annotation, metadata$Diagnosis)

# %%
eec_pops = names(table(metadata$annotation))[12:21]
anno = as.vector(metadata$annotation)
anno[ anno %in% eec_pops] = "EEC"
table(metadata$annotation,anno)
# Out:
#                        anno
#                         BEST2+ Goblet cell BEST4+ epithelial CLDN10+ cells
#   Stem cells                             0                 0             0
#   TA                                     0                 0             0
#   Enterocyte                             0                 0             0
#   Colonocyte                             0                 0             0
#   BEST4+ epithelial                      0              4555             0
#   BEST2+ Goblet cell                  3025                 0             0
#   Goblet cell                            0                 0             0
#   Paneth                                 0                 0             0
#   Tuft                                   0                 0             0
#   Microfold cell                         0                 0             0
#   Progenitor (NEUROG3+)                  0                 0             0
#   EC cells (TAC1+)                       0                 0             0
#   EC cells (NPW+)                        0                 0             0
#   EECs                                   0                 0             0
#   M/X cells (MLN/GHRL+)                  0                 0             0
#   L cells (PYY+)                         0                 0             0
#   I cells (CCK+)                         0                 0             0
#   D cells (SST+)                         0                 0             0
#   K cells (GIP+)                         0                 0             0
#   N cells (NTS+)                         0                 0             0
#   β cells (INS+)                         0                 0             0
#   Proximal progenitor                    0                 0             0
#   Distal progenitor                      0                 0             0
#   CLDN10+ cells                          0                 0           260
#   Germ                                   0                 0             0
#                        anno
#                         Colonocyte Distal progenitor   EEC Enterocyte  Germ
#   Stem cells                     0                 0     0          0     0
#   TA                             0                 0     0          0     0
#   Enterocyte                     0                 0     0      37460     0
#   Colonocyte                 14133                 0     0          0     0
#   BEST4+ epithelial              0                 0     0          0     0
#   BEST2+ Goblet cell             0                 0     0          0     0
#   Goblet cell                    0                 0     0          0     0
#   Paneth                         0                 0     0          0     0
#   Tuft                           0                 0     0          0     0
#   Microfold cell                 0                 0     0          0     0
#   Progenitor (NEUROG3+)          0                 0     0          0     0
#   EC cells (TAC1+)               0                 0   422          0     0
#   EC cells (NPW+)                0                 0    59          0     0
#   EECs                           0                 0   485          0     0
#   M/X cells (MLN/GHRL+)          0                 0   297          0     0
#   L cells (PYY+)                 0                 0   118          0     0
#   I cells (CCK+)                 0                 0   227          0     0
#   D cells (SST+)                 0                 0   143          0     0
#   K cells (GIP+)                 0                 0    83          0     0
#   N cells (NTS+)                 0                 0    44          0     0
#   β cells (INS+)                 0                 0    31          0     0
#   Proximal progenitor            0                 0     0          0     0
#   Distal progenitor              0              3077     0          0     0
#   CLDN10+ cells                  0                 0     0          0     0
#   Germ                           0                 0     0          0    14
#                        anno
#                         Goblet cell Microfold cell Paneth Progenitor (NEUROG3+)
#   Stem cells                      0              0      0                     0
#   TA                              0              0      0                     0
#   Enterocyte                      0              0      0                     0
#   Colonocyte                      0              0      0                     0
#   BEST4+ epithelial               0              0      0                     0
#   BEST2+ Goblet cell              0              0      0                     0
#   Goblet cell                  5330              0      0                     0
#   Paneth                          0              0   3064                     0
#   Tuft                            0              0      0                     0
#   Microfold cell                  0            457      0                     0
#   Progenitor (NEUROG3+)           0              0      0                   336
#   EC cells (TAC1+)                0              0      0                     0
#   EC cells (NPW+)                 0              0      0                     0
#   EECs                            0              0      0                     0
#   M/X cells (MLN/GHRL+)           0              0      0                     0
#   L cells (PYY+)                  0              0      0                     0
#   I cells (CCK+)                  0              0      0                     0
#   D cells (SST+)                  0              0      0                     0
#   K cells (GIP+)                  0              0      0                     0
#   N cells (NTS+)                  0              0      0                     0
#   β cells (INS+)                  0              0      0                     0
#   Proximal progenitor             0              0      0                     0
#   Distal progenitor               0              0      0                     0
#   CLDN10+ cells                   0              0      0                     0
#   Germ                            0              0      0                     0
#                        anno
#                         Proximal progenitor Stem cells    TA  Tuft
#   Stem cells                              0       8077     0     0
#   TA                                      0          0 50024     0
#   Enterocyte                              0          0     0     0
#   Colonocyte                              0          0     0     0
#   BEST4+ epithelial                       0          0     0     0
#   BEST2+ Goblet cell                      0          0     0     0
#   Goblet cell                             0          0     0     0
#   Paneth                                  0          0     0     0
#   Tuft                                    0          0     0   737
#   Microfold cell                          0          0     0     0
#   Progenitor (NEUROG3+)                   0          0     0     0
#   EC cells (TAC1+)                        0          0     0     0
#   EC cells (NPW+)                         0          0     0     0
#   EECs                                    0          0     0     0
#   M/X cells (MLN/GHRL+)                   0          0     0     0
#   L cells (PYY+)                          0          0     0     0
#   I cells (CCK+)                          0          0     0     0
#   D cells (SST+)                          0          0     0     0
#   K cells (GIP+)                          0          0     0     0
#   N cells (NTS+)                          0          0     0     0
#   β cells (INS+)                          0          0     0     0
#   Proximal progenitor                  9655          0     0     0
#   Distal progenitor                       0          0     0     0
#   CLDN10+ cells                           0          0     0     0
#   Germ                                    0          0     0     0

# %%
good_pops = c("Stem cells", "TA", "Enterocyte", "Goblet cell", "Paneth", "EEC", "Tuft")
anno = factor(anno, levels = good_pops); names(anno) = rownames(metadata)
table(anno)
# Out:
# anno
#  Stem cells          TA  Enterocyte Goblet cell      Paneth         EEC
#        8077       50024       37460        5330        3064        1909
#        Tuft
#         737

# %%
good_cells = names(anno)[ anno %in% good_pops &
                        metadata$Age_group == "Adult"]
x = table(anno[ good_cells])
x
setdiff(good_pops, names(x))
# Out:
#  Stem cells          TA  Enterocyte Goblet cell      Paneth         EEC
#        1022       43485        9649         699        2655         112
#        Tuft
#         569
# character(0)

# %%
tuft_cells = intersect(good_cells, names(anno)[ anno == "Tuft"])
length(tuft_cells)

sort(table(as.vector(metadata[ tuft_cells, "Sample.name"])))
# Out:
# [1] 569
# A33 (414C) A30 (398B) A38 (432C) A34 (417C) A32 (411C) A39 (440C) A26 (386C)
#          4         15         47         58         80        115        250

# %%
k=500
samp_cells = unlist(tapply(good_cells, anno[good_cells], function(x) sample(x, min(length(x), k))))
table(anno[ samp_cells])
length(samp_cells)
# Out:
#  Stem cells          TA  Enterocyte Goblet cell      Paneth         EEC
#         500         500         500         500         500         112
#        Tuft
#         500
# [1] 3112

# %%
scdb_init("saved_work/", force_reinit = T)
id = "teichman_all_filtered"
suffix = "_f"; id_f = paste0(id, suffix)
sc_2d = scdb_mc2d(id_f); sc_cl = scdb_mc(paste0(id, suffix)); sc_mat = scdb_mat(id)

cells = names(sc_cl@mc)
cell_stats = sc_mat@cell_metadata[cells,]
colnames(cell_stats) = gsub(" ", ".", colnames(cell_stats))
colnames(cell_stats) = gsub("\\(|\\)", "_", colnames(cell_stats))
# Out:
# initializing scdb to saved_work/

# %%
umicount = as.matrix(read.delim("results/teichman_all/umicount.txt", stringsAsFactors = F, row.names = 1))[,1]
head(umicount)
# Out:
# AAACGGGCAGTCAGAG-1-Human_colon_16S8000511
#                                     39976
# AAAGCAATCCGTTGTC-1-Human_colon_16S8000511
#                                     18320
# AACACGTTCCTGCAGG-1-Human_colon_16S8000511
#                                      6295
# AACCATGGTCGGCATC-1-Human_colon_16S8000511
#                                     17850
# AACCGCGTCAACACCA-1-Human_colon_16S8000511
#                                     23801
# AACGTTGTCGGGAGTA-1-Human_colon_16S8000511
#                                      1070

# %%
#doublet = cell_stats$doublet_scores; names(doublet) = rownames(cell_stats)
good_cells = rownames(cell_stats)#names(which(doublet < 0.1))
length(good_cells)
# Out:
# [1] 15184

# %%
data = X[,good_cells]
data_n = sweep(data,2,colSums(data),"/") * 1000
table(anno[ good_cells])
# Out:
#  Stem cells          TA  Enterocyte Goblet cell      Paneth         EEC
#         346        2297        8996         166        2538          13
#        Tuft
#          74

# %%
plot_feature_maps = function(i, genes, nr = 2, nc = 3, rfac = 5) {
#genes = c("KIT", "POU2F3", "IL4R", "IL27RA", "IL17RB"); i = 1; nr = 1; nc = 1; rfac = 5
    #all_cells = sample(good_cells)
    cb = 1 / nc
    rb = 1 / nr
    locs = cbind(rep(seq_len(nc) - 1, nr), rep(rev(seq_len(nr)) - 1, each = nc))
    gene = genes[i]
    umis = sc_mat@mat[gene, names(sc_cl@mc)]
    umis_n = umis / umicount[ names(umis)]
    all_cells = names(sort(umis_n))
    vals = umis_n[all_cells]
    pos_vals = log(1 + 1 * vals[ vals > 0])
    pos_vals = pmin(pos_vals, quantile(pos_vals, 0.99))
    val_n = rep(1, length(all_cells)); names(val_n) = all_cells
    val_n[ names(pos_vals)] = round(100 * pos_vals / max(pos_vals)) + 1
    grad = colorRampPalette(c("gray90", "gray90", brewer.pal(3, "Reds")))(101)
    #grad = colorRampPalette(c("gray80","gray80", "blue3"))(101)
    cell_ord = names(val_n) #sort(val_n))
    r = locs[i,2]; c = locs[i,1]
    par(fig = c(c / nc, c / nc + cb * 0.85, r / nr, r / nr + rb * 0.85), mar = rep(0.5,4), new = (i > 1))
    #plot(df[,"x"], df[,"y"], pch = 20, col = grad[1],
    #    axes = F, xlab = "", ylab = "", cex = 0.7, main = gene)
    df = cbind(x = sc_2d@sc_x[ all_cells], y = sc_2d@sc_y[ all_cells], col = grad[ val_n[ all_cells]], 
               rx = round(sc_2d@sc_x[ all_cells] / rfac), ry = round(sc_2d@sc_y[ all_cells] / rfac))
    df = df[ !duplicated(df[, c("col", "rx", "ry")]),]
    dim(df)
    plot(df[,"x"], df[,"y"], pch = 20, cex = 0.7, col = df[,"col"], axes = F, xlab = "", ylab = "", main = gene)
    par (fig = c(c / nc + cb * 0.9, c / nc + cb * 1, r / nr + rb * 0.3, r / nr + rb * 0.6), new=T)
    ax = seq(0, max(pos_vals), length.out = length(grad))
    image(y = ax, t(seq_along(grad)), axes = F, col = grad)
    box(); axis(2, at = quantile(ax, c(0,1)), labels = round(quantile(ax, c(0,1)),3), las = 2)
}

# %%
X = plot_two_genes_fp(id_f, "AVIL", "POU2F3")
tuft_mc = rownames(X)[ X[,1] > 1]
tuft_mc_cells = names(sc_cl@mc)[ sc_cl@mc %in% tuft_mc]

# Identify tuft cells
plot(sc_2d@sc_x, sc_2d@sc_y, pch = 20, col = "gray",axes = F, xlab = "", ylab = "", cex = 0.7)
points(sc_2d@sc_x[ tuft_mc_cells], sc_2d@sc_y[ tuft_mc_cells], pch = 20, col = "red", cex = 0.7)
legend("topright", c("Tuft", "Non-tuft"), pch = 20, col = c("red", "gray"))
# Out:
# plot without title
# plot without title

# %%
genes = c("KIT", "POU2F3")
pdf(paste0(outdir, "/FigS2g.pdf"), height=5, width=10, useDingbats=F)
plot_feature_maps(1, "KIT", rfac = 1, nr=1, nc = 1)
dev.off()

pdf(paste0(outdir, "/FigS5a_right.pdf"), height=5, width=10, useDingbats=F)
plot_feature_maps(1, "KIT", rfac = 1, nr=1, nc = 1)
dev.off()

invisible(sapply(seq_along(genes), plot_feature_maps, genes, rfac = 1, nr=1, nc = 2))
# Out:
# png
#   2
# png
#   2
# Plot with title “POU2F3”

# %%
genes = c("KIT", "IL13RA1", "IL4R", "IL27RA", "IL17RB")
m = t(apply(data_n[genes, good_cells], 1, tapply, anno[ good_cells], mean))
IM = log2(m[, rev(colnames(m))] + 0.02)
exp_freq = t(apply(data[genes, good_cells] > 0, 1, tapply, anno[ good_cells], mean)) * 100
exp_freq = exp_freq[ ,colnames(IM)]

grad = colorRampPalette(c("white", brewer.pal(9, "YlOrBr")))(101)

p = function() {
    par(mar = c(3,10,1,3))
    matplot.2(t(IM), t(exp_freq), grad=grad, cex_lim = seq(0,100, by = 25))
}

p()
pdf(paste0(outdir, "/Fig2a.pdf"), height=10, width=15, useDingbats = F)
p()
dev.off()

genes = c("POU2F3", "POU2F3")
m = t(apply(data_n[genes, good_cells], 1, tapply, anno[ good_cells], mean))
IM = log2(m[, rev(colnames(m))] + 0.02)
exp_freq = t(apply(data[genes, good_cells] > 0, 1, tapply, anno[ good_cells], mean)) * 100
exp_freq = exp_freq[ ,colnames(IM)]

grad = colorRampPalette(c("white", brewer.pal(9, "YlOrBr")))(101)

p = function() {
    par(mar = c(3,10,1,3))
    matplot.2(t(IM), t(exp_freq), grad=grad, cex_lim = seq(0,100, by = 25))
}

p()
pdf(paste0(outdir, "/FigS5a_left.pdf"), height=10, width=15, useDingbats = F)
p()
dev.off()

genes = union(read.table("annotations//stem_genes.txt", stringsAsFactors = F)[[1]],
              c("MEX3A", "ANXA1", "TACSTD2", "PROX1"))

m = t(apply(data_n[genes, good_cells], 1, tapply, anno[ good_cells], mean))
IM = log2(m + 0.02)
exp_freq = t(apply(data[genes, ] > 0, 1, tapply, anno[ colnames(data_n)], mean)) * 100
exp_freq = exp_freq[ ,colnames(m)]

p()
pdf(paste0(outdir, "/FigS8b.pdf"), height=10, width=15, useDingbats = F)
p()
dev.off()
# Out:
# png
#   2
# plot without title
# png
#   2
# plot without title
# png
#   2
# plot without title

# %%
gene = "AVIL"
m = tapply(data_n[gene, good_cells], anno[ good_cells], mean)

p = function() {
    par(mar = c(15,5,1,1))
    barplot(m,las=2, ylab = "AVIL expression / 1,000 transcripts", col = ifelse(names(m) == "Tuft", "antiquewhite", "gray80"))    
}

p()
pdf(paste0(outdir, "/Fig1a.pdf"), useDingbats = F)
p()
dev.off()
# Out:
# png
#   2
# plot without title

# %%
l = names(table(anno[ good_cells]))
l

# %%
#apply(Z, 2, function(x) names(head(sort(x,T),10)))
genes = c("LGR5", "OLFM4", "APOA1", "APOB", "ALDOB", "ZG16", "MUC2", "FCGBP",
         "DEFA6", "DEFA5", "REG3A", "CHGB", "CHGA", "LCN15", "AVIL", "KIT", "POU2F3")
gene_anno = c(rep("Stem cells", 2), rep(l[-(1:2)], each = 3)); 
gene_anno = factor(gene_anno, levels = unique(gene_anno));
names(gene_anno) = genes
gene_anno

# %%
ds = .downsamp(obj@assays$RNA[, samp_cells], 1000)
grad = colorRampPalette(c("blue", "white", "red"))(1000)

p = function() {
    par(fig=c(0,0.95,0,0.95), mar = c(5,5,5,5))
    C = cor(t(log(1 + ds[genes,]))); diag(C) = NA
    image.2(C, b=T, hct = gene_anno, vct = gene_anno); box()
    par(fig=c(0.95,1,0.3,0.6), new=T, mar = rep(0.5,4))
    zlim = max(abs(C), na.rm = T)
    ax = seq(-zlim, zlim, length.out = length(grad))
    image(y = ax, t(seq_along(grad)), axes = F, col = grad)
    box(); axis(2, at = quantile(ax), labels = round(quantile(ax),2), las = 2)

}

p()
pdf(paste0(outdir, "/Fig3m.pdf"), useDingbats = F)
p()
dev.off()

# %% [markdown]
# ## Analyze Hickey's paper

# %%
id = "hickey_all"
sc_mat = scdb_mat(id)
sc_mat@ncells

# %%
cell_stats = sc_mat@cell_metadata[ sc_mat@cells,]
head(cell_stats)

write.table(colnames(cell_stats))

# %%
cell_stats$patient = vecsplit(cell_stats$file, "-", 1)
table(cell_stats$patient)

# %%
hickey_tuft_cells = rownames(cell_stats)[cell_stats$CellType == "Tuft" & cell_stats$source == "Jejunum"]
length(hickey_tuft_cells)

# %%
hickey_umis = read_large_umis(id, cells = hickey_tuft_cells)
hickey_n = sweep(hickey_umis, 2, colSums(hickey_umis), "/") * 1000
foc = log(1 + 7 * hickey_n)

dim(foc)

# %%
dim(data)
table(anno)
sum(anno == "Tuft")
head(anno)

# %%
tuft_cells = names(anno)[ !is.na(anno) & anno == "Tuft" & metadata$Age_group == "Adult"]
length(tuft_cells)
tuft_umis = obj@assays$RNA[, tuft_cells]

shared_genes = intersect(rownames(tuft_umis), rownames(hickey_umis))
length(shared_genes)

shared_umis = cbind(tuft_umis[ shared_genes, ], hickey_umis[ shared_genes,])

# %%
comb = ifelse(colnames(shared_umis) %in% hickey_tuft_cells, "Hickey", "Teichman"); names(comb) = colnames(shared_umis)
med_uc = tapply(colSums(shared_umis), comb, median)
med_uc

# %%
shared_n = sweep(shared_umis, 2, colSums(shared_umis), "/") * 1000
shared_foc = log(1 + 7 * shared_n)

# %%
tuft_genes = read.delim("figures/figure3_5/activation_genes_sc_heatmap.txt", stringsAsFactors = F, row.names=1)

shared_top_genes = setdiff(intersect(rownames(shared_umis), rownames(tuft_genes)), c())
modules = t(apply(shared_foc[ shared_top_genes,], 2, tapply, tuft_genes[ shared_top_genes, "anno"], sum))
head(modules)
tail(modules)

# %%
dim(modules)
head(metadata)
teichman_pat = as.vector(metadata[ tuft_cells, "Sample.name"]); names(teichman_pat) = tuft_cells
table(teichman_pat)

hickey_pat = as.vector(cell_stats[ colnames(hickey_umis), "patient"]); names(hickey_pat) = colnames(hickey_umis)
table(hickey_pat)

# %%
good_te_pats = names(which(table(teichman_pat) > 20))
good_te_cells = names(teichman_pat)[ teichman_pat %in% good_te_pats]
plot_density_points( modules[ good_te_cells, "Tuft-3"], teichman_pat[good_te_cells], with_box = T)
#plot_density_points( modules[ good_te_cells, "Tuft-4"], teichman_pat[good_te_cells], with_box = T)

# %%
good_hi_pats = names(which(table(hickey_pat) > 20))
good_hi_cells = names(hickey_pat)[ hickey_pat %in% good_hi_pats]
plot_density_points( modules[ good_hi_cells, "Tuft-3"], hickey_pat[good_hi_cells], with_box = T)
#plot_density_points( modules[ good_hi_cells, "Tuft-4"], hickey_pat[good_hi_cells], with_box = T)

# %% [markdown]
# tecihman_sh = shuffle_umis_matrix(tuft_umis[ shared_genes,])
# hickey_sh = shuffle_umis_matrix(hickey_umis[ shared_genes,])
#
# shared_sh = cbind(tecihman_sh, hickey_sh)
# shared_sh_n = sweep(shared_sh, 2, colSums(shared_sh), "/") * 1000
# shared_sh_foc = log(1 + 7 * shared_sh_n)
# sh_modules = t(apply(shared_sh_foc[ shared_top_genes,], 2, tapply, top_genes[ shared_top_genes, "anno"], sum))

# %%
anchor_genes = c("TOP2A", "UBE2C", "MKI67", "CDK1", "PCNA", "MCM4")

gset = scdb_gset("10x_lateral_f")
c = unique(gset@gene_set[ anchor_genes])
c
cc_genes = names(gset@gene_set[ gset@gene_set %in% c])
cc_umis = colSums(shared_foc[ cc_genes,])
plot(density(log2(cc_umis[ comb == "Teichman"]))); abline(v = 3)
plot(density(log2(cc_umis[ comb == "Hickey"]))); abline(v = 3.5)

# %%
X = rbind(table(teichman_pat[ good_te_cells], log2(cc_umis[ good_te_cells]) > 3),
table(hickey_pat[ good_hi_cells], log2(cc_umis[ good_hi_cells]) > 3.5))
cc_freq = (X / rowSums(X))[,2]

cc_mean = mean(cc_freq)
cc_err = std.error(cc_freq)

p = function() {
    plot(runif(length(cc_freq), -0.2, 0.2), cc_freq, pch = 21, bg = 2 + (names(cc_freq) %in% good_te_pats), xlim = c(-0.5,0.5), axes = F,
        xlab = "", ylab = "% proliferating tuft cells", xaxs = "i")
    segments(0, cc_mean - cc_err, y1 = cc_mean + cc_err)
    points(0, cc_mean, pch = 20, cex = 3)
    axis(2, las = 2); axis(1, at = 0, labels = "")

}

p()
pdf(paste0(outdir, "/FigS4i.pdf"), height=6, width=2, useDingbats = F)
p()
dev.off()

# %% [markdown]
# ## Analyze Regev's paper

# %%
scdb_init("saved_work/", force_reinit = T)
id = "regev_10x"
sc_mat = scdb_mat(id)
sc_mat@ncells

# %%
cell_stats = sc_mat@cell_metadata[ sc_mat@cells,]
head(cell_stats)

write.table(colnames(cell_stats))

# %%
summarize.table(table(cell_stats$Cluster, cell_stats$Health))

# %%
gene = "KIT"
umis = as.matrix(sc_mat@mat[gene,])
table(cell_stats$Cluster, umis)

# %% [markdown]
# #patient = paste0(cell_stats$Subject, "@", ifelse(cell_stats$Health == "Healthy", "Healthy", "IBD")); names(patient) = rownames(cell_stats)
# patient = paste0(cell_stats$Subject, "@", cell_stats$Health); names(patient) = rownames(cell_stats)
# table(patient)

# %% [markdown]
# X = table(patient, cell_stats$Cluster == "Tuft")
# tuft_freq = (X / rowSums(X))[,2]
# tuft_freq

# %% [markdown]
# table(pat2health)
# pat2health = vecsplit(names(tuft_freq), "@", 2)
#
# boxplot(tuft_freq * 100 ~ pat2health)
#
# wilcox.test(tuft_freq[ pat2health == "Healthy"], tuft_freq[ pat2health == "IBD"])

# %% [markdown]
# table(cell_stats$Cluster)

# %%
#eec_pops = names(table(metadata$annotation))[12:21]
anno = paste0(cell_stats$Cluster, "@", cell_stats$Health)
#anno[ anno %in% eec_pops] = "EEC"
names(anno) = rownames(cell_stats)
table(anno)

# %%
k=100
good_cells = names(anno)
samp_cells = unlist(tapply(good_cells, anno[good_cells], function(x) sample(x, min(length(x), k))))
table(anno[ samp_cells])
length(samp_cells)

# %%
umis = read_large_umis(id ,cells = samp_cells)
umis_n = sweep(umis,2,colSums(umis),"/") * 1000

# %% [markdown]
# new_id = "regev_sampled"
# mcell_mat_ignore_cells(new_mat_id=new_id, mat_id=id, samp_cells, reverse=T)

# %%
grad = colorRampPalette(c("white", brewer.pal(9, "YlOrBr")))(101)
group_by = list(cell_stats[ colnames(umis), "Cluster"], 
            factor(cell_stats[ colnames(umis), "Health"], levels = c("Healthy", "Non-inflamed", "Inflamed")))
gene = "KIT"
m = tapply(umis_n[gene,], group_by, mean)
exp_freq = tapply(umis_n[gene,] > 0, group_by, mean) * 100

p = function() {
    par(mar = c(5,15,1,1))
    matplot.2(m, exp_freq, grad=grad, cex_lim = seq(0,100, by = 25))
}

p()
pdf(paste0(outdir, "/FigS2j.pdf"), height=7, width = 10, useDingbats = F)
p()
dev.off()

# %% [markdown]
# ## Primary sort-seq data

# %%
scdb_init("saved_work", force=T)

sc_mat = scdb_mat("all_lulu")
sc_mat@ncells

cell_stats = sc_mat@cell_metadata
head(cell_stats)
# Out:
# initializing scdb to saved_work
# [1] 3834
#                      amp_batch_id batch_set_id batch_seq_id cell_barcode
# HUB.JO.s037_AAACAGGC HUB.JO.s037  HUB.JO.s037  HUB.JO.s037  AAACAGGC
# HUB.JO.s037_AAAGCGGA HUB.JO.s037  HUB.JO.s037  HUB.JO.s037  AAAGCGGA
# HUB.JO.s037_AAAGGCTG HUB.JO.s037  HUB.JO.s037  HUB.JO.s037  AAAGGCTG
# HUB.JO.s037_AACACGCA HUB.JO.s037  HUB.JO.s037  HUB.JO.s037  AACACGCA
# HUB.JO.s037_AACATGGG HUB.JO.s037  HUB.JO.s037  HUB.JO.s037  AACATGGG
# HUB.JO.s037_AACCCAAC HUB.JO.s037  HUB.JO.s037  HUB.JO.s037  AACCCAAC
#                      umicount mt_count coord id              idx source
# HUB.JO.s037_AAACAGGC 7296     1280     H18   H18@HUB.JO.s037 1   Ileum
# HUB.JO.s037_AAAGCGGA 3461      626     P12   P12@HUB.JO.s037 4   Ileum
# HUB.JO.s037_AAAGGCTG 4062     1019     O10   O10@HUB.JO.s037 4   Ileum
# HUB.JO.s037_AACACGCA 8352     1471     L20   L20@HUB.JO.s037 2   Ileum
# HUB.JO.s037_AACATGGG 4986      692     P10   P10@HUB.JO.s037 4   Ileum
# HUB.JO.s037_AACCCAAC 8453     1449     O15   O15@HUB.JO.s037 4   Ileum
#                      type     gating       treatment age   clover
# HUB.JO.s037_AAACAGGC organoid AVIL-Clover+ no_cyto   adult AVIL
# HUB.JO.s037_AAAGCGGA organoid AVIL-Clover+ IL4+IL13  adult AVIL
# HUB.JO.s037_AAAGGCTG organoid AVIL-Clover+ IL4+IL13  adult AVIL
# HUB.JO.s037_AACACGCA organoid AVIL-Clover+ IL4+IL13  adult AVIL
# HUB.JO.s037_AACATGGG organoid AVIL-Clover+ IL4+IL13  adult AVIL
# HUB.JO.s037_AACCCAAC organoid AVIL-Clover+ IL4+IL13  adult AVIL

# %%
bad_genes = grep("^MT-|^IG[H,L]|^ERCC", sc_mat@genes, v=T)
good_genes = setdiff(sc_mat@genes, bad_genes)

# %%
with(cell_stats[ cell_stats$type == "tissue",], table(paste0(source, "@", age), as.vector(gating)))

primary_cells = rownames(cell_stats)[ cell_stats$type == "tissue" & 
                    cell_stats$umicount > 500 &
                    cell_stats$mt_count / cell_stats$umicount < 0.4]
length(primary_cells)
# Out:
#
#                  CD117+ EPCAM+
#   Colon@adult       383      0
#   Colon@fetal        49     48
#   Duodenum@fetal     52      0
#   Ileum@adult       600    168
#   Ileum@fetal       163      0
#   Jejunum@fetal      72      0
# [1] 780

# %%
table(cell_stats[ primary_cells, "age"], cell_stats[ primary_cells, "source"])

comb = paste0(cell_stats[ primary_cells, "source"], "@", cell_stats[ primary_cells, "age"], "@", cell_stats[ primary_cells, "gating"])
names(comb) = primary_cells
table(comb)
# Out:
#
#         Colon Duodenum Ileum Jejunum
#   adult   271        0   417       0
#   fetal    14       15    45      18
# comb
#    Colon@adult@CD117+    Colon@fetal@CD117+    Colon@fetal@EPCAM+
#                   271                    11                     3
# Duodenum@fetal@CD117+    Ileum@adult@CD117+    Ileum@adult@EPCAM+
#                    15                   311                   106
#    Ileum@fetal@CD117+  Jejunum@fetal@CD117+
#                    45                    18

# %%
primary_umis = read_large_umis("all_lulu", cells = primary_cells)
primary_umis = primary_umis[ good_genes,]
primary_n = sweep(primary_umis, 2, colSums(primary_umis), "/") * 1000
primary_foc = log(1 + 7 * primary_n)

# %%
tuft_genes = read.delim("figures/figure3_5/activation_genes_sc_heatmap.txt", stringsAsFactors = F, row.names=1)

core_genes = rownames(tuft_genes)[ tuft_genes$anno == "Core"]
score = colSums(primary_foc[ core_genes,])
par(mar = c(10,3,1,1))
plot_density_points(score, comb, las = 2, with_box = T)
# Out:
# plot without title

# %%
tuft4_genes = rownames(tuft_genes)[ tuft_genes$anno == "Tuft-4"]
score4 = colSums(primary_foc[ tuft4_genes,])

tuft3_genes = rownames(tuft_genes)[ tuft_genes$anno == "Tuft-3"]
score3 = colSums(primary_foc[ tuft3_genes,])

module_genes = rownames(tuft_genes)[ tuft_genes$anno == "Tuft-2"]
score2 = colSums(primary_foc[ module_genes,])

par(mar = c(10,3,1,1))
plot_density_points(score3, comb, las = 2, with_box = T)
plot_density_points(score4, comb, las = 2, with_box = T)
# Out:
# plot without title
# plot without title

# %%
l = names(table(comb))
plot(score3, score4, pch = 21, bg = rainbow(8)[ as.numeric(factor(comb))])
legend("topright", l, pch = 21, pt.bg = rainbow(8))
# Out:
# plot without title

# %%
l = names(table(comb))
plot(score3, score, pch = 21, bg = rainbow(8)[ as.numeric(factor(comb))])
legend("topright", l, pch = 21, pt.bg = rainbow(8))
# Out:
# plot without title

# %%
sort(table(comb))
l = c('Colon@adult@CD117+', 'Ileum@adult@CD117+')
good_cells = names(comb)[ comb %in% l]
table(comb[ good_cells])
# Out:
# comb
#    Colon@fetal@EPCAM+    Colon@fetal@CD117+ Duodenum@fetal@CD117+
#                     3                    11                    15
#  Jejunum@fetal@CD117+    Ileum@fetal@CD117+    Ileum@adult@EPCAM+
#                    18                    45                   106
#    Colon@adult@CD117+    Ileum@adult@CD117+
#                   271                   311
# Colon@adult@CD117+ Ileum@adult@CD117+
#                271                311

# %%
cell_anno = ifelse(score3 > 22, "Tuft-3", "None"); names(cell_anno) = names(score3)
table(comb[ good_cells], cell_anno[ good_cells])
# Out:
#
#                      None Tuft-3
#   Colon@adult@CD117+  246     25
#   Ileum@adult@CD117+  295     16

# %%
#good_cells = names(comb)[ comb %in% l]
comb2 = paste0(comb[ good_cells],"@", cell_anno[good_cells]); names(comb2) = good_cells
table(comb2)
m = t(apply(primary_n[, good_cells], 1, tapply, comb2[ good_cells], mean))
# Out:
# comb2
#   Colon@adult@CD117+@None Colon@adult@CD117+@Tuft-3   Ileum@adult@CD117+@None
#                       246                        25                       295
# Ileum@adult@CD117+@Tuft-3
#                        16

# %%
reg = 0.04
z2tuft = log2((reg + m[,"Ileum@adult@CD117+@Tuft-3"]) / (reg + m[,"Ileum@adult@CD117+@None"]))
#z2ep = log2((reg + m[,"Ileum@adult@CD117+@Tuft-3"]) / (reg + m[,"Ileum@adult@EPCAM+@Tuft-3"]))

#plot(z2ep, z2tuft, type = "n")
#text(z2ep, z2tuft, names(z2ep), col = anno_cols[genes[ names(z2ep), "anno"]], cex = 0.5)

# %%
diff_genes = scr_chi_square_diff_genes(primary_umis, 
            g1 = names(which(comb2[ good_cells] == "Ileum@adult@CD117+@Tuft-3")), 
            g2 = names(which(comb2[ good_cells] == "Ileum@adult@CD117+@None")), pval = 1e-3, fdr = T)

tuft3_diff = intersect(diff_genes, tuft3_genes)
length(tuft3_diff)
#write.table(names(head(sort(z2tuft[ tuft3_genes], T))), quote = F, row.names = F)
# Out:
# [1] 87

# %%
cc_col = "#a36250"

x = sort(z2tuft[ tuft3_genes])
p = function() {
    barplot(x, horiz = T, 
            col = ifelse(names(x) %in% tuft3_diff, cc_col, "white"), 
            names.arg = rep("", length(tuft3_genes)))    
}

p()
pdf(paste0(outdir, "/FigS4h.pdf"), height=12, width=8)
p()
dev.off()
# Out:
# png
#   2
# plot without title

# %%
cc_genes = setdiff(rownames(tuft_genes)[ tuft_genes$anno == "Tuft-3"], c("MUC2", "ITLN1", "TK1", "PIGR", "H4C3"))
cc_disp_genes = union(names(head(sort(z2tuft[ cc_genes], T), 20)), c("PCNA", "UBE2C"))
sort(cc_disp_genes)
# Out:
#  [1] "ANP32E" "AURKB"  "CCDC34" "CCNB1"  "CDC20"  "CENPF"  "CKS1B"  "CKS2"
#  [9] "GTSE1"  "H2AX"   "HMGB2"  "MKI67"  "PCNA"   "PRC1"   "PRR11"  "PTTG1"
# [17] "RRM2"   "STMN1"  "TMPO"   "TOP2A"  "TUBB4B" "UBE2C"

# %%
core_genes = c("AVIL", "POU2F3", "KIT")#, "ALOX5AP", "BMX", "SH2D6")
disp_genes = unique(c(core_genes, cc_disp_genes))
disp_genes

hct = factor(c(rep("Core", length(core_genes)), 
        rep("CC", length(cc_disp_genes))),
        levels = c("Core", "CC")); 
names(hct) = disp_genes
# Out:
#  [1] "AVIL"   "POU2F3" "KIT"    "TOP2A"  "MKI67"  "RRM2"   "CDC20"  "PTTG1"
#  [9] "CENPF"  "AURKB"  "PRR11"  "CCNB1"  "CKS1B"  "GTSE1"  "PRC1"   "ANP32E"
# [17] "CKS2"   "CCDC34" "TUBB4B" "H2AX"   "STMN1"  "HMGB2"  "TMPO"   "PCNA"
# [25] "UBE2C"

# %%
tissue = factor(paste0(cell_stats[ good_cells, "source"], "-",
                      cell_stats[ good_cells, "age"])); names(tissue) = good_cells

table(tissue)
# Out:
# tissue
# Colon-adult Ileum-adult
#         271         311

# %%
IM2 = as.matrix(log(1 + 7 * primary_umis[ disp_genes, good_cells]))

vct = paste0(comb[ colnames(IM2)], "@", cell_anno[ colnames(IM2)]); names(vct) = colnames(IM2)

IM2 = IM2[,order(score3[ colnames(IM2)])]
IM2 = IM2[,order(vct[ colnames(IM2)])]
IM2 = IM2[ order(hct[ rownames(IM2)], rowSums(primary_umis[ rownames(IM2),])),]

# %%
max_row = t(apply(IM2, 1, tapply, comb[ colnames(IM2)], quantile, 0.99))
head(max_row)

IM3 = pmin((0 + IM2) / (0 + max_row[, comb[ colnames(IM2)]]), 1)
# Out:
#        Colon@adult@CD117+ Ileum@adult@CD117+
# KIT    4.669840           3.912023
# POU2F3 4.745419           4.147300
# AVIL   5.384495           4.521789
# PRC1   2.268024           2.708050
# GTSE1  2.708050           3.339670
# AURKB  2.079442           3.367296

# %%
grad = colorRampPalette(c("white", brewer.pal(9, "YlOrBr")))(1000)

p = function() { 
    par(mar = c(0.5,7,0.5,0.5), fig = c(0,0.9,0.1,1))
    image.2(IM3, col = grad, annotate = "rows",
        vct = vct[ colnames(IM2)], hct = hct[ rownames(IM3)])
    box()
    par(mar = c(0.5,0.5,0.5,0.5), fig = c(0.95,1,0.3,0.6), new = T)
#    image(matrix(seq_len(ncol(IM2))), axes = F, col = anno_cols[ as.vector(sort(cell_anno[ colnames(IM2)]))])
#     box()
    image(y = seq(min(IM3), max(IM3), length.out = length(grad)), t(seq_along(grad)), col=grad, axes=F)
    axis(2,las=2); box()
#    par(mar = c(0.5,7,0.5,0.5), fig = c(0,0.9,0.1,0.15), new = T)
    par(mar = c(0.5,7,0.5,0.5), fig = c(0,0.9,0.05,0.1), new = T)
    image(matrix(seq_len(ncol(IM3))), axes = F, ylab = "cell", las = 2,
          col = c("gray80", cc_col)[ as.numeric(factor(cell_anno[ colnames(IM3)]))]); box()

#    image(matrix(seq_len(ncol(IM2))), axes = F, ylab = "gating",
#          col = c(anno_cols["Tuft-1"], "cyan3")[ as.numeric(gating[ colnames(IM2)])]); box()
    par(mar = c(0.5,7,0.5,0.5), fig = c(0,0.9,0,0.05), new = T)
    image(matrix(seq_len(ncol(IM3))), axes = F, ylab = "source",
          col = rainbow(3, alpha = 0.5)[ as.numeric(tissue[ colnames(IM3)])]); box()
}

p()
pdf(paste0(outdir, "/FigS4g.pdf"), height=12, width=8)
p()
dev.off()
# Out:
# zlim: 0<>1
# zlim: 0<>1
# png
#   2
# plot without title

# %%
no_cc = names(which(cell_anno != "Tuft-3"))
l = c('Colon@adult@CD117+', 'Ileum@adult@CD117+')#, 'Ileum@fetal@CD117+')
good_cells = intersect(no_cc, names(comb)[ comb %in% l])

ds = .downsamp(primary_umis[,good_cells], 500)
uc = rowSums(primary_umis[,good_cells])
nc = rowSums(primary_umis[, good_cells] > 0)

bad_genes = grep("^RPL|^RPS|^SNOR|^A[CLP][0-9]|^MTCO[0-9]|^MT|^MTRNR|^MTND|^MTC|^MTA|^HLA-|^IG[K,H]", rownames(primary_umis), v=T)
exp_genes = intersect(setdiff(union(names(which(uc > 150 & nc > 50)), rownames(genes)), c(bad_genes, "MALAT1")), 
                      rownames(ds))
core_genes = c("AVIL", "POU2F3", "KIT")
exp_genes = union(exp_genes, core_genes)
length(exp_genes)

cells = intersect(colnames(ds), names(comb)[comb %in% l])
table(comb[cells])
table(comb[no_cc])
#C = cor(log(1 + t(ds[ exp_genes, cells])), modules[cells,])
#dim(C)
# Out:
# [1] 2386
# Colon@adult@CD117+ Ileum@adult@CD117+
#                239                279
#    Colon@adult@CD117+    Colon@fetal@CD117+    Colon@fetal@EPCAM+
#                   246                     8                     2
# Duodenum@fetal@CD117+    Ileum@adult@CD117+    Ileum@adult@EPCAM+
#                    15                   295                    98
#    Ileum@fetal@CD117+  Jejunum@fetal@CD117+
#                    42                    17

# %%
X = log(1 + ds[intersect(exp_genes, union(core_genes, rownames(tuft_genes)[ tuft_genes$anno == "Tuft-4"])),  cells])
C = sapply(l, function(c) {
    cells = intersect(colnames(X), names(which(comb == c)));
    cor(t(X[, cells]), score4[cells], m = "spearman")})
dim(C)
rownames(C) = rownames(X)
# Out:
# Warning message in cor(t(X[, cells]), score4[cells], m = "spearman"):
# “the standard deviation is zero”
# [1] 18  2

# %%
table(comb)
# Out:
# comb
#    Colon@adult@CD117+    Colon@fetal@CD117+    Colon@fetal@EPCAM+
#                   271                    11                     3
# Duodenum@fetal@CD117+    Ileum@adult@CD117+    Ileum@adult@EPCAM+
#                    15                   311                   106
#    Ileum@fetal@CD117+  Jejunum@fetal@CD117+
#                    45                    18

# %%
head(C)
dim(X)
dim(C)
plot(C[,1], C[,2], type = "n"); grid(col = "red")
text(C[,1], C[,2], rownames(C))

diff_genes = setdiff(names(which(apply(C[,1:2],1,max) > 0.13)), c())
sort(diff_genes)
# Out:
#         Colon@adult@CD117+ Ileum@adult@CD117+
# CDHR2    0.1677638246      0.1397214
# MGLL     0.2544248476      0.1530388
# SYNGR2   0.1317694690      0.1828499
# VIPR1   -0.0006917683      0.2278603
# DNAL1    0.0830396378      0.1399971
# TNFSF10  0.1024983264      0.1323310
# [1]  18 518
# [1] 18  2
#  [1] "CDHR2"   "CHP1"    "DNAL1"   "MGLL"    "MGST3"   "PAPSS2"  "PHGR1"
#  [8] "SYNGR2"  "TNFSF10" "TRAK1"   "VIPR1"
# plot without title

# %%
core_genes = c("AVIL", "POU2F3", "KIT")
disp_genes = unique(c(core_genes, diff_genes))
disp_genes
# Out:
#  [1] "AVIL"    "POU2F3"  "KIT"     "CDHR2"   "MGLL"    "SYNGR2"  "VIPR1"
#  [8] "DNAL1"   "TNFSF10" "MGST3"   "TRAK1"   "CHP1"    "PAPSS2"  "PHGR1"

# %%
IM2 = as.matrix(primary_foc[ disp_genes, good_cells])

hct = factor(c(rep("Core", length(core_genes)), 
        rep("Activation", length(diff_genes))), levels = c("Core", "Activation")); names(hct) = disp_genes
vct = paste0(comb[ colnames(IM2)], "@", cell_anno[ colnames(IM2)]); names(vct) = colnames(IM2)

IM2 = IM2[,order(score4[ colnames(IM2)])]
IM2 = IM2[,order(vct[ colnames(IM2)])]
#IM2 = IM2[ order(hct[ rownames(IM2)], rowSums(primary_umis[ rownames(IM2),])),]
gene_rank = rowSums(primary_umis[ rownames(IM2),]) * (1 - 2 * (C[ rownames(IM2),1] - C[ rownames(IM2),2] > 0))
IM2 = IM2[ order(hct[ rownames(IM2)], gene_rank),]
    
max_row = t(apply(IM2, 1, tapply, vct[ colnames(IM2)], quantile, 0.99))
head(max_row)

IM3 = pmin((0 + IM2) / (0 + max_row[, vct[ colnames(IM2)]]), 1)
# Out:
#        Colon@adult@CD117+@None Ileum@adult@CD117+@None
# AVIL   3.309530                3.633922
# KIT    3.084548                2.672758
# POU2F3 3.228081                3.392330
# CDHR2  2.029041                3.449842
# CHP1   2.536029                2.576288
# PAPSS2 2.863983                2.845949

# %%
grad = colorRampPalette(c("white", brewer.pal(9, "YlOrBr")))(1000)
p = function() { 
    par(mar = c(0.5,7,0.5,0.5), fig = c(0,0.9,0.05,0.95))
    image.2(IM3, col = grad, annotate = "rows",
        vct = vct[ colnames(IM3)], hct = hct[ rownames(IM3)])
    box()
    par(fig = c(0,0.9,0,0.05), new = T)
    image(matrix(seq_len(ncol(IM3))), axes = F, 
          col = rainbow(3, alpha = 0.5)[ as.numeric(tissue[ colnames(IM3)])], ylab = "tissue")
    box()
    par(fig = c(0,0.9,0.95,1), new = T)
    plot(score4[ colnames(IM3)], type = "h", xaxs = "i", axes = F, ylab = "score"); axis(2, las = 2)
    box()
    par(fig = c(0.95,1,0.3,0.6), new=T, mar = c(0.5,0.5,0.5,0.5))
    image(y = seq(min(IM3), max(IM3), length.out = length(grad)), t(seq_along(grad)), col=grad, axes=F)
    axis(2,las=2); box()
}

p()

pdf(paste0(outdir, "/FigS4j.pdf"), height=8, width=8)
p()
dev.off()
#png(paste0(outdir, "/organoid_tuft_genes_on_both.png"), height=max(2000, nrow(IM2) * 12), width=1500)
#p()
#dev.off()
# Out:
# zlim: 0<>1
# zlim: 0<>1
# png
#   2
# plot without title

# %%
c = "Ileum@adult@CD117+"
#genes = c("MGST3", "PHGR1", "VIPR1", "CDHR2", "SYNGR2")
genes = c("MGLL", "VIPR1", "SDCBP2", "KRT20", "PHGR1", "VIPR1-AS1")
#genes = setdiff(names(which(C[,c]> 0.1)), c("AREG")) # colon
genes
# Out:
# [1] "MGLL"      "VIPR1"     "SDCBP2"    "KRT20"     "PHGR1"     "VIPR1-AS1"

# %%
#genes = c("PHGR1", "VIPR1", "CDHR2")
bs = 30
skip = 5
n = length(cells)
ss4 = names(sort(score4[cells]))
eyes = seq(1, n - bs, by = skip)
#m2 = rep(NA, length(eyes))
m = list()
for (gene in genes) {
    m[[gene]] = matrix(NA, nrow = length(eyes), ncol = 3)
    for (j in seq_along(eyes)) {
        i = eyes[j]
        #message(i, "-", i + bs)
        sub_cells = ss4[i:(i + bs)]
    #    m2[j] = mean(ds[ gene, sub_cells])
        m[[gene]][j,] = binconf(sum(ds[gene, sub_cells]), sum(ds[, sub_cells])) * mean(ds[, sub_cells])
    }
    m[[gene]] = m[[gene]] / max(m[[gene]][,1])    
}
m
#plot(m2, m[,1])
# Out:
# $MGLL
#             [,1]        [,2]      [,3]
#  [1,] 0.06666667 0.003419553 0.3775657
#  [2,] 0.06666667 0.003419553 0.3775657
#  [3,] 0.06666667 0.003419553 0.3775657
#  [4,] 0.13333333 0.036565546 0.4860688
#  [5,] 0.06666667 0.003419553 0.3775657
#  [6,] 0.06666667 0.003419553 0.3775657
#  [7,] 0.06666667 0.003419553 0.3775657
#  [8,] 0.06666667 0.003419553 0.3775657
#  [9,] 0.06666667 0.003419553 0.3775657
# [10,] 0.00000000 0.000000000 0.2560338
# [11,] 0.00000000 0.000000000 0.2560338
# [12,] 0.00000000 0.000000000 0.2560338
# [13,] 0.00000000 0.000000000 0.2560338
# [14,] 0.00000000 0.000000000 0.2560338
# [15,] 0.00000000 0.000000000 0.2560338
# [16,] 0.00000000 0.000000000 0.2560338
# [17,] 0.00000000 0.000000000 0.2560338
# [18,] 0.00000000 0.000000000 0.2560338
# [19,] 0.13333333 0.036565546 0.4860688
# [20,] 0.20000000 0.068020253 0.5879144
# [21,] 0.20000000 0.068020253 0.5879144
# [22,] 0.20000000 0.068020253 0.5879144
# [23,] 0.20000000 0.068020253 0.5879144
# [24,] 0.20000000 0.068020253 0.5879144
# [25,] 0.06666667 0.003419553 0.3775657
# [26,] 0.06666667 0.003419553 0.3775657
# [27,] 0.00000000 0.000000000 0.2560338
# [28,] 0.00000000 0.000000000 0.2560338
# [29,] 0.00000000 0.000000000 0.2560338
# [30,] 0.00000000 0.000000000 0.2560338
# [31,] 0.00000000 0.000000000 0.2560338
# [32,] 0.26666667 0.103706039 0.6855289
# [33,] 0.33333333 0.142387952 0.7801473
# [34,] 0.40000000 0.183335671 0.8724999
# [35,] 0.46666667 0.226074770 0.9630611
# [36,] 0.46666667 0.226074770 0.9630611
# [37,] 0.53333333 0.270276413 1.0521598
# [38,] 0.40000000 0.183335671 0.8724999
# [39,] 0.20000000 0.068020253 0.5879144
# [40,] 0.20000000 0.068020253 0.5879144
# [41,] 0.06666667 0.003419553 0.3775657
# [42,] 0.13333333 0.036565546 0.4860688
# [43,] 0.06666667 0.003419553 0.3775657
# [44,] 0.06666667 0.003419553 0.3775657
# [45,] 0.06666667 0.003419553 0.3775657
# [46,] 0.06666667 0.003419553 0.3775657
# [47,] 0.06666667 0.003419553 0.3775657
# [48,] 0.00000000 0.000000000 0.2560338
# [49,] 0.06666667 0.003419553 0.3775657
# [50,] 0.13333333 0.036565546 0.4860688
# [51,] 0.13333333 0.036565546 0.4860688
# [52,] 0.26666667 0.103706039 0.6855289
# [53,] 0.33333333 0.142387952 0.7801473
# [54,] 0.33333333 0.142387952 0.7801473
# [55,] 0.40000000 0.183335671 0.8724999
# [56,] 0.33333333 0.142387952 0.7801473
# [57,] 0.33333333 0.142387952 0.7801473
# [58,] 0.26666667 0.103706039 0.6855289
# [59,] 0.20000000 0.068020253 0.5879144
# [60,] 0.26666667 0.103706039 0.6855289
# [61,] 0.20000000 0.068020253 0.5879144
# [62,] 0.13333333 0.036565546 0.4860688
# [63,] 0.13333333 0.036565546 0.4860688
# [64,] 0.20000000 0.068020253 0.5879144
# [65,] 0.20000000 0.068020253 0.5879144
# [66,] 0.13333333 0.036565546 0.4860688
# [67,] 0.13333333 0.036565546 0.4860688
# [68,] 0.26666667 0.103706039 0.6855289
# [69,] 0.26666667 0.103706039 0.6855289
# [70,] 0.20000000 0.068020253 0.5879144
# [71,] 0.20000000 0.068020253 0.5879144
# [72,] 0.26666667 0.103706039 0.6855289
# [73,] 0.33333333 0.142387952 0.7801473
# [74,] 0.20000000 0.068020253 0.5879144
# [75,] 0.26666667 0.103706039 0.6855289
# [76,] 0.33333333 0.142387952 0.7801473
# [77,] 0.33333333 0.142387952 0.7801473
# [78,] 0.53333333 0.270276413 1.0521598
# [79,] 0.66666667 0.362169983 1.2268668
# [80,] 0.73333333 0.409541794 1.3127953
# [81,] 0.86666667 0.506572071 1.4823656
# [82,] 0.86666667 0.506572071 1.4823656
# [83,] 1.00000000 0.606126551 1.6494117
# [84,] 0.80000000 0.457705843 1.3979315
# [85,] 0.60000000 0.315701562 1.1400349
# [86,] 0.73333333 0.409541794 1.3127953
# [87,] 0.53333333 0.270276413 1.0521598
# [88,] 0.53333333 0.270276413 1.0521598
# [89,] 0.60000000 0.315701562 1.1400349
# [90,] 0.53333333 0.270276413 1.0521598
# [91,] 0.80000000 0.457705843 1.3979315
# [92,] 0.73333333 0.409541794 1.3127953
# [93,] 0.93333333 0.556066295 1.5661717
# [94,] 0.86666667 0.506572071 1.4823656
# [95,] 0.66666667 0.362169983 1.2268668
# [96,] 0.66666667 0.362169983 1.2268668
# [97,] 0.46666667 0.226074770 0.9630611
# [98,] 0.46666667 0.226074770 0.9630611
#
# $VIPR1
#             [,1]        [,2]      [,3]
#  [1,] 0.07142857 0.003663807 0.4045347
#  [2,] 0.07142857 0.003663807 0.4045347
#  [3,] 0.07142857 0.003663807 0.4045347
#  [4,] 0.14285714 0.039177371 0.5207881
#  [5,] 0.14285714 0.039177371 0.5207881
#  [6,] 0.14285714 0.039177371 0.5207881
#  [7,] 0.07142857 0.003663807 0.4045347
#  [8,] 0.07142857 0.003663807 0.4045347
#  [9,] 0.07142857 0.003663807 0.4045347
# [10,] 0.00000000 0.000000000 0.2743219
# [11,] 0.00000000 0.000000000 0.2743219
# [12,] 0.00000000 0.000000000 0.2743219
# [13,] 0.00000000 0.000000000 0.2743219
# [14,] 0.00000000 0.000000000 0.2743219
# [15,] 0.00000000 0.000000000 0.2743219
# [16,] 0.07142857 0.003663807 0.4045347
# [17,] 0.14285714 0.039177371 0.5207881
# [18,] 0.14285714 0.039177371 0.5207881
# [19,] 0.14285714 0.039177371 0.5207881
# [20,] 0.14285714 0.039177371 0.5207881
# [21,] 0.14285714 0.039177371 0.5207881
# [22,] 0.14285714 0.039177371 0.5207881
# [23,] 0.07142857 0.003663807 0.4045347
# [24,] 0.14285714 0.039177371 0.5207881
# [25,] 0.21428571 0.072878843 0.6299083
# [26,] 0.21428571 0.072878843 0.6299083
# [27,] 0.21428571 0.072878843 0.6299083
# [28,] 0.14285714 0.039177371 0.5207881
# [29,] 0.14285714 0.039177371 0.5207881
# [30,] 0.07142857 0.003663807 0.4045347
# [31,] 0.00000000 0.000000000 0.2743219
# [32,] 0.00000000 0.000000000 0.2743219
# [33,] 0.07142857 0.003663807 0.4045347
# [34,] 0.14285714 0.039177371 0.5207881
# [35,] 0.14285714 0.039177371 0.5207881
# [36,] 0.14285714 0.039177371 0.5207881
# [37,] 0.14285714 0.039177371 0.5207881
# [38,] 0.28571429 0.111113613 0.7344953
# [39,] 0.21428571 0.072878843 0.6299083
# [40,] 0.14285714 0.039177371 0.5207881
# [41,] 0.21428571 0.072878843 0.6299083
# [42,] 0.28571429 0.111113613 0.7344953
# [43,] 0.28571429 0.111113613 0.7344953
# [44,] 0.14285714 0.039177371 0.5207881
# [45,] 0.14285714 0.039177371 0.5207881
# [46,] 0.14285714 0.039177371 0.5207881
# [47,] 0.14285714 0.039177371 0.5207881
# [48,] 0.07142857 0.003663807 0.4045347
# [49,] 0.07142857 0.003663807 0.4045347
# [50,] 0.07142857 0.003663807 0.4045347
# [51,] 0.07142857 0.003663807 0.4045347
# [52,] 0.07142857 0.003663807 0.4045347
# [53,] 0.00000000 0.000000000 0.2743219
# [54,] 0.00000000 0.000000000 0.2743219
# [55,] 0.00000000 0.000000000 0.2743219
# [56,] 0.00000000 0.000000000 0.2743219
# [57,] 0.00000000 0.000000000 0.2743219
# [58,] 0.00000000 0.000000000 0.2743219
# [59,] 0.07142857 0.003663807 0.4045347
# [60,] 0.14285714 0.039177371 0.5207881
# [61,] 0.14285714 0.039177371 0.5207881
# [62,] 0.14285714 0.039177371 0.5207881
# [63,] 0.14285714 0.039177371 0.5207881
# [64,] 0.14285714 0.039177371 0.5207881
# [65,] 0.07142857 0.003663807 0.4045347
# [66,] 0.07142857 0.003663807 0.4045347
# [67,] 0.07142857 0.003663807 0.4045347
# [68,] 0.07142857 0.003663807 0.4045347
# [69,] 0.21428571 0.072878843 0.6299083
# [70,] 0.35714286 0.152558520 0.8358721
# [71,] 0.35714286 0.152558520 0.8358721
# [72,] 0.35714286 0.152558520 0.8358721
# [73,] 0.28571429 0.111113613 0.7344953
# [74,] 0.28571429 0.111113613 0.7344953
# [75,] 0.14285714 0.039177371 0.5207881
# [76,] 0.07142857 0.003663807 0.4045347
# [77,] 0.07142857 0.003663807 0.4045347
# [78,] 0.14285714 0.039177371 0.5207881
# [79,] 0.14285714 0.039177371 0.5207881
# [80,] 0.14285714 0.039177371 0.5207881
# [81,] 0.21428571 0.072878843 0.6299083
# [82,] 0.35714286 0.152558520 0.8358721
# [83,] 0.50000000 0.242222967 1.0318512
# [84,] 0.50000000 0.242222967 1.0318512
# [85,] 0.57142857 0.289581871 1.1273140
# [86,] 0.78571429 0.438794779 1.4065664
# [87,] 0.78571429 0.438794779 1.4065664
# [88,] 0.78571429 0.438794779 1.4065664
# [89,] 0.57142857 0.289581871 1.1273140
# [90,] 0.57142857 0.289581871 1.1273140
# [91,] 0.42857143 0.196431076 0.9348213
# [92,] 0.28571429 0.111113613 0.7344953
# [93,] 0.35714286 0.152558520 0.8358721
# [94,] 0.35714286 0.152558520 0.8358721
# [95,] 0.42857143 0.196431076 0.9348213
# [96,] 0.71428571 0.388039267 1.3145001
# [97,] 0.78571429 0.438794779 1.4065664
# [98,] 1.00000000 0.595785316 1.6780411
#
# $SDCBP2
#       [,1]       [,2]      [,3]
#  [1,]  0.0 0.00000000 0.7681014
#  [2,]  0.0 0.00000000 0.7681014
#  [3,]  0.0 0.00000000 0.7681014
#  [4,]  0.0 0.00000000 0.7681014
#  [5,]  0.0 0.00000000 0.7681014
#  [6,]  0.0 0.00000000 0.7681014
#  [7,]  0.0 0.00000000 0.7681014
#  [8,]  0.0 0.00000000 0.7681014
#  [9,]  0.0 0.00000000 0.7681014
# [10,]  0.0 0.00000000 0.7681014
# [11,]  0.0 0.00000000 0.7681014
# [12,]  0.0 0.00000000 0.7681014
# [13,]  0.0 0.00000000 0.7681014
# [14,]  0.0 0.00000000 0.7681014
# [15,]  0.0 0.00000000 0.7681014
# [16,]  0.0 0.00000000 0.7681014
# [17,]  0.2 0.01025866 1.1326971
# [18,]  0.2 0.01025866 1.1326971
# [19,]  0.2 0.01025866 1.1326971
# [20,]  0.2 0.01025866 1.1326971
# [21,]  0.2 0.01025866 1.1326971
# [22,]  0.2 0.01025866 1.1326971
# [23,]  0.2 0.01025866 1.1326971
# [24,]  0.0 0.00000000 0.7681014
# [25,]  0.0 0.00000000 0.7681014
# [26,]  0.0 0.00000000 0.7681014
# [27,]  0.0 0.00000000 0.7681014
# [28,]  0.0 0.00000000 0.7681014
# [29,]  0.0 0.00000000 0.7681014
# [30,]  0.0 0.00000000 0.7681014
# [31,]  0.0 0.00000000 0.7681014
# [32,]  0.0 0.00000000 0.7681014
# [33,]  0.0 0.00000000 0.7681014
# [34,]  0.0 0.00000000 0.7681014
# [35,]  0.0 0.00000000 0.7681014
# [36,]  0.0 0.00000000 0.7681014
# [37,]  0.0 0.00000000 0.7681014
# [38,]  0.0 0.00000000 0.7681014
# [39,]  0.0 0.00000000 0.7681014
# [40,]  0.0 0.00000000 0.7681014
# [41,]  0.0 0.00000000 0.7681014
# [42,]  0.0 0.00000000 0.7681014
# [43,]  0.0 0.00000000 0.7681014
# [44,]  0.2 0.01025866 1.1326971
# [45,]  0.2 0.01025866 1.1326971
# [46,]  0.2 0.01025866 1.1326971
# [47,]  0.2 0.01025866 1.1326971
# [48,]  0.2 0.01025866 1.1326971
# [49,]  0.2 0.01025866 1.1326971
# [50,]  0.2 0.01025866 1.1326971
# [51,]  0.2 0.01025866 1.1326971
# [52,]  0.4 0.10969664 1.4582065
# [53,]  0.4 0.10969664 1.4582065
# [54,]  0.4 0.10969664 1.4582065
# [55,]  0.4 0.10969664 1.4582065
# [56,]  0.2 0.01025866 1.1326971
# [57,]  0.2 0.01025866 1.1326971
# [58,]  0.0 0.00000000 0.7681014
# [59,]  0.0 0.00000000 0.7681014
# [60,]  0.0 0.00000000 0.7681014
# [61,]  0.0 0.00000000 0.7681014
# [62,]  0.0 0.00000000 0.7681014
# [63,]  0.0 0.00000000 0.7681014
# [64,]  0.0 0.00000000 0.7681014
# [65,]  0.0 0.00000000 0.7681014
# [66,]  0.2 0.01025866 1.1326971
# [67,]  0.2 0.01025866 1.1326971
# [68,]  0.2 0.01025866 1.1326971
# [69,]  0.4 0.10969664 1.4582065
# [70,]  0.4 0.10969664 1.4582065
# [71,]  0.4 0.10969664 1.4582065
# [72,]  0.4 0.10969664 1.4582065
# [73,]  0.4 0.10969664 1.4582065
# [74,]  0.4 0.10969664 1.4582065
# [75,]  0.4 0.10969664 1.4582065
# [76,]  0.6 0.20406076 1.7637433
# [77,]  0.6 0.20406076 1.7637433
# [78,]  0.6 0.20406076 1.7637433
# [79,]  0.4 0.10969664 1.4582065
# [80,]  0.6 0.20406076 1.7637433
# [81,]  0.4 0.10969664 1.4582065
# [82,]  0.6 0.20406076 1.7637433
# [83,]  0.4 0.10969664 1.4582065
# [84,]  0.4 0.10969664 1.4582065
# [85,]  0.8 0.31111812 2.0565868
# [86,]  0.8 0.31111812 2.0565868
# [87,]  0.8 0.31111812 2.0565868
# [88,]  0.8 0.31111812 2.0565868
# [89,]  1.0 0.42716385 2.3404420
# [90,]  1.0 0.42716385 2.3404420
# [91,]  0.8 0.31111812 2.0565868
# [92,]  0.6 0.20406076 1.7637433
# [93,]  0.8 0.31111812 2.0565868
# [94,]  0.8 0.31111812 2.0565868
# [95,]  0.6 0.20406076 1.7637433
# [96,]  0.8 0.31111812 2.0565868
# [97,]  0.8 0.31111812 2.0565868
# [98,]  0.6 0.20406076 1.7637433
#
# $KRT20
#             [,1]        [,2]      [,3]
#  [1,] 0.00000000 0.000000000 0.1828813
#  [2,] 0.00000000 0.000000000 0.1828813
#  [3,] 0.00000000 0.000000000 0.1828813
#  [4,] 0.04761905 0.002442538 0.2696898
#  [5,] 0.09523810 0.026118247 0.3471920
#  [6,] 0.09523810 0.026118247 0.3471920
#  [7,] 0.09523810 0.026118247 0.3471920
#  [8,] 0.09523810 0.026118247 0.3471920
#  [9,] 0.09523810 0.026118247 0.3471920
# [10,] 0.09523810 0.026118247 0.3471920
# [11,] 0.09523810 0.026118247 0.3471920
# [12,] 0.04761905 0.002442538 0.2696898
# [13,] 0.04761905 0.002442538 0.2696898
# [14,] 0.04761905 0.002442538 0.2696898
# [15,] 0.09523810 0.026118247 0.3471920
# [16,] 0.09523810 0.026118247 0.3471920
# [17,] 0.04761905 0.002442538 0.2696898
# [18,] 0.09523810 0.026118247 0.3471920
# [19,] 0.09523810 0.026118247 0.3471920
# [20,] 0.09523810 0.026118247 0.3471920
# [21,] 0.09523810 0.026118247 0.3471920
# [22,] 0.04761905 0.002442538 0.2696898
# [23,] 0.04761905 0.002442538 0.2696898
# [24,] 0.14285714 0.048585895 0.4199389
# [25,] 0.14285714 0.048585895 0.4199389
# [26,] 0.14285714 0.048585895 0.4199389
# [27,] 0.14285714 0.048585895 0.4199389
# [28,] 0.14285714 0.048585895 0.4199389
# [29,] 0.14285714 0.048585895 0.4199389
# [30,] 0.09523810 0.026118247 0.3471920
# [31,] 0.04761905 0.002442538 0.2696898
# [32,] 0.04761905 0.002442538 0.2696898
# [33,] 0.04761905 0.002442538 0.2696898
# [34,] 0.09523810 0.026118247 0.3471920
# [35,] 0.19047619 0.074075742 0.4896635
# [36,] 0.19047619 0.074075742 0.4896635
# [37,] 0.23809524 0.101705680 0.5572481
# [38,] 0.23809524 0.101705680 0.5572481
# [39,] 0.23809524 0.101705680 0.5572481
# [40,] 0.33333333 0.161481978 0.6879008
# [41,] 0.28571429 0.130954050 0.6232142
# [42,] 0.23809524 0.101705680 0.5572481
# [43,] 0.23809524 0.101705680 0.5572481
# [44,] 0.14285714 0.048585895 0.4199389
# [45,] 0.19047619 0.074075742 0.4896635
# [46,] 0.09523810 0.026118247 0.3471920
# [47,] 0.04761905 0.002442538 0.2696898
# [48,] 0.04761905 0.002442538 0.2696898
# [49,] 0.14285714 0.048585895 0.4199389
# [50,] 0.19047619 0.074075742 0.4896635
# [51,] 0.14285714 0.048585895 0.4199389
# [52,] 0.14285714 0.048585895 0.4199389
# [53,] 0.23809524 0.101705680 0.5572481
# [54,] 0.23809524 0.101705680 0.5572481
# [55,] 0.14285714 0.048585895 0.4199389
# [56,] 0.09523810 0.026118247 0.3471920
# [57,] 0.09523810 0.026118247 0.3471920
# [58,] 0.14285714 0.048585895 0.4199389
# [59,] 0.23809524 0.101705680 0.5572481
# [60,] 0.19047619 0.074075742 0.4896635
# [61,] 0.19047619 0.074075742 0.4896635
# [62,] 0.19047619 0.074075742 0.4896635
# [63,] 0.23809524 0.101705680 0.5572481
# [64,] 0.23809524 0.101705680 0.5572481
# [65,] 0.28571429 0.130954050 0.6232142
# [66,] 0.19047619 0.074075742 0.4896635
# [67,] 0.33333333 0.161481978 0.6879008
# [68,] 0.33333333 0.161481978 0.6879008
# [69,] 0.42857143 0.225501115 0.8143106
# [70,] 0.38095238 0.193054581 0.7515427
# [71,] 0.42857143 0.225501115 0.8143106
# [72,] 0.38095238 0.193054581 0.7515427
# [73,] 0.42857143 0.225501115 0.8143106
# [74,] 0.42857143 0.225501115 0.8143106
# [75,] 0.38095238 0.193054581 0.7515427
# [76,] 0.33333333 0.161481978 0.6879008
# [77,] 0.33333333 0.161481978 0.6879008
# [78,] 0.28571429 0.130954050 0.6232142
# [79,] 0.33333333 0.161481978 0.6879008
# [80,] 0.28571429 0.130954050 0.6232142
# [81,] 0.28571429 0.130954050 0.6232142
# [82,] 0.33333333 0.161481978 0.6879008
# [83,] 0.28571429 0.130954050 0.6232142
# [84,] 0.33333333 0.161481978 0.6879008
# [85,] 0.23809524 0.101705680 0.5572481
# [86,] 0.38095238 0.193054581 0.7515427
# [87,] 0.52380952 0.292529853 0.9377109
# [88,] 0.47619048 0.258692845 0.8763334
# [89,] 0.66666667 0.397190211 1.1186940
# [90,] 0.85714286 0.542297304 1.3544449
# [91,] 0.90476190 0.579347074 1.4126097
# [92,] 0.85714286 0.542297304 1.3544449
# [93,] 0.85714286 0.542297304 1.3544449
# [94,] 1.00000000 0.654215008 1.5281707
# [95,] 0.90476190 0.579347074 1.4126097
# [96,] 0.76190476 0.469071748 1.2372415
# [97,] 0.80952381 0.505530865 1.2959969
# [98,] 0.76190476 0.469071748 1.2372415
#
# $PHGR1
#             [,1]       [,2]      [,3]
#  [1,] 0.07407407 0.02880723 0.1904247
#  [2,] 0.09259259 0.03955221 0.2167076
#  [3,] 0.09259259 0.03955221 0.2167076
#  [4,] 0.11111111 0.05092658 0.2423611
#  [5,] 0.12962963 0.06279855 0.2675170
#  [6,] 0.09259259 0.03955221 0.2167076
#  [7,] 0.07407407 0.02880723 0.1904247
#  [8,] 0.14814815 0.07507678 0.2922666
#  [9,] 0.18518519 0.10060277 0.3407963
# [10,] 0.25925926 0.15446286 0.4350477
# [11,] 0.27777778 0.16836849 0.4581699
# [12,] 0.25925926 0.15446286 0.4350477
# [13,] 0.31481481 0.19659534 0.5039988
# [14,] 0.22222222 0.12714051 0.3883143
# [15,] 0.22222222 0.12714051 0.3883143
# [16,] 0.18518519 0.10060277 0.3407963
# [17,] 0.18518519 0.10060277 0.3407963
# [18,] 0.24074074 0.14071446 0.4117682
# [19,] 0.25925926 0.15446286 0.4350477
# [20,] 0.24074074 0.14071446 0.4117682
# [21,] 0.24074074 0.14071446 0.4117682
# [22,] 0.25925926 0.15446286 0.4350477
# [23,] 0.18518519 0.10060277 0.3407963
# [24,] 0.16666667 0.08769488 0.3166764
# [25,] 0.09259259 0.03955221 0.2167076
# [26,] 0.09259259 0.03955221 0.2167076
# [27,] 0.11111111 0.05092658 0.2423611
# [28,] 0.07407407 0.02880723 0.1904247
# [29,] 0.09259259 0.03955221 0.2167076
# [30,] 0.09259259 0.03955221 0.2167076
# [31,] 0.11111111 0.05092658 0.2423611
# [32,] 0.29629630 0.18241679 0.4811495
# [33,] 0.29629630 0.18241679 0.4811495
# [34,] 0.33333333 0.21089340 0.5267286
# [35,] 0.31481481 0.19659534 0.5039988
# [36,] 0.31481481 0.19659534 0.5039988
# [37,] 0.29629630 0.18241679 0.4811495
# [38,] 0.16666667 0.08769488 0.3166764
# [39,] 0.12962963 0.06279855 0.2675170
# [40,] 0.22222222 0.12714051 0.3883143
# [41,] 0.25925926 0.15446286 0.4350477
# [42,] 0.27777778 0.16836849 0.4581699
# [43,] 0.27777778 0.16836849 0.4581699
# [44,] 0.25925926 0.15446286 0.4350477
# [45,] 0.25925926 0.15446286 0.4350477
# [46,] 0.14814815 0.07507678 0.2922666
# [47,] 0.16666667 0.08769488 0.3166764
# [48,] 0.20370370 0.11376161 0.3646654
# [49,] 0.24074074 0.14071446 0.4117682
# [50,] 0.24074074 0.14071446 0.4117682
# [51,] 0.31481481 0.19659534 0.5039988
# [52,] 0.35185185 0.22530164 0.5493482
# [53,] 0.38888889 0.25441695 0.5942886
# [54,] 0.38888889 0.25441695 0.5942886
# [55,] 0.37037037 0.23981189 0.5718658
# [56,] 0.40740741 0.26911040 0.6166230
# [57,] 0.35185185 0.22530164 0.5493482
# [58,] 0.29629630 0.18241679 0.4811495
# [59,] 0.25925926 0.15446286 0.4350477
# [60,] 0.25925926 0.15446286 0.4350477
# [61,] 0.27777778 0.16836849 0.4581699
# [62,] 0.27777778 0.16836849 0.4581699
# [63,] 0.24074074 0.14071446 0.4117682
# [64,] 0.27777778 0.16836849 0.4581699
# [65,] 0.29629630 0.18241679 0.4811495
# [66,] 0.24074074 0.14071446 0.4117682
# [67,] 0.22222222 0.12714051 0.3883143
# [68,] 0.18518519 0.10060277 0.3407963
# [69,] 0.20370370 0.11376161 0.3646654
# [70,] 0.20370370 0.11376161 0.3646654
# [71,] 0.20370370 0.11376161 0.3646654
# [72,] 0.24074074 0.14071446 0.4117682
# [73,] 0.27777778 0.16836849 0.4581699
# [74,] 0.29629630 0.18241679 0.4811495
# [75,] 0.31481481 0.19659534 0.5039988
# [76,] 0.33333333 0.21089340 0.5267286
# [77,] 0.24074074 0.14071446 0.4117682
# [78,] 0.20370370 0.11376161 0.3646654
# [79,] 0.20370370 0.11376161 0.3646654
# [80,] 0.18518519 0.10060277 0.3407963
# [81,] 0.16666667 0.08769488 0.3166764
# [82,] 0.20370370 0.11376161 0.3646654
# [83,] 0.27777778 0.16836849 0.4581699
# [84,] 0.38888889 0.25441695 0.5942886
# [85,] 0.42592593 0.28388655 0.6388747
# [86,] 0.53703704 0.37402540 0.7709030
# [87,] 0.57407407 0.40455011 0.8144341
# [88,] 0.61111111 0.43527653 0.8577634
# [89,] 0.62962963 0.45070980 0.8793579
# [90,] 0.48148148 0.32866244 0.7051824
# [91,] 0.50000000 0.34372293 0.7271498
# [92,] 0.44444444 0.29874027 0.6610489
# [93,] 0.40740741 0.26911040 0.6166230
# [94,] 0.55555556 0.38926133 0.7926950
# [95,] 0.51851852 0.35884496 0.7490556
# [96,] 0.75925926 0.55988205 1.0293807
# [97,] 0.72222222 0.52850223 0.9867048
# [98,] 1.00000000 0.76676137 1.3038636
#
# $`VIPR1-AS1`
#            [,1]       [,2]     [,3]
#  [1,] 0.0000000 0.00000000 1.280169
#  [2,] 0.0000000 0.00000000 1.280169
#  [3,] 0.0000000 0.00000000 1.280169
#  [4,] 0.0000000 0.00000000 1.280169
#  [5,] 0.0000000 0.00000000 1.280169
#  [6,] 0.0000000 0.00000000 1.280169
#  [7,] 0.0000000 0.00000000 1.280169
#  [8,] 0.0000000 0.00000000 1.280169
#  [9,] 0.0000000 0.00000000 1.280169
# [10,] 0.0000000 0.00000000 1.280169
# [11,] 0.0000000 0.00000000 1.280169
# [12,] 0.0000000 0.00000000 1.280169
# [13,] 0.0000000 0.00000000 1.280169
# [14,] 0.0000000 0.00000000 1.280169
# [15,] 0.0000000 0.00000000 1.280169
# [16,] 0.0000000 0.00000000 1.280169
# [17,] 0.0000000 0.00000000 1.280169
# [18,] 0.0000000 0.00000000 1.280169
# [19,] 0.0000000 0.00000000 1.280169
# [20,] 0.0000000 0.00000000 1.280169
# [21,] 0.0000000 0.00000000 1.280169
# [22,] 0.0000000 0.00000000 1.280169
# [23,] 0.0000000 0.00000000 1.280169
# [24,] 0.0000000 0.00000000 1.280169
# [25,] 0.0000000 0.00000000 1.280169
# [26,] 0.0000000 0.00000000 1.280169
# [27,] 0.0000000 0.00000000 1.280169
# [28,] 0.0000000 0.00000000 1.280169
# [29,] 0.0000000 0.00000000 1.280169
# [30,] 0.0000000 0.00000000 1.280169
# [31,] 0.0000000 0.00000000 1.280169
# [32,] 0.0000000 0.00000000 1.280169
# [33,] 0.0000000 0.00000000 1.280169
# [34,] 0.0000000 0.00000000 1.280169
# [35,] 0.0000000 0.00000000 1.280169
# [36,] 0.0000000 0.00000000 1.280169
# [37,] 0.3333333 0.01709776 1.887828
# [38,] 0.3333333 0.01709776 1.887828
# [39,] 0.3333333 0.01709776 1.887828
# [40,] 0.3333333 0.01709776 1.887828
# [41,] 0.6666667 0.18282773 2.430344
# [42,] 0.6666667 0.18282773 2.430344
# [43,] 0.6666667 0.18282773 2.430344
# [44,] 0.3333333 0.01709776 1.887828
# [45,] 0.3333333 0.01709776 1.887828
# [46,] 0.3333333 0.01709776 1.887828
# [47,] 0.0000000 0.00000000 1.280169
# [48,] 0.0000000 0.00000000 1.280169
# [49,] 0.0000000 0.00000000 1.280169
# [50,] 0.0000000 0.00000000 1.280169
# [51,] 0.0000000 0.00000000 1.280169
# [52,] 0.0000000 0.00000000 1.280169
# [53,] 0.0000000 0.00000000 1.280169
# [54,] 0.0000000 0.00000000 1.280169
# [55,] 0.0000000 0.00000000 1.280169
# [56,] 0.0000000 0.00000000 1.280169
# [57,] 0.0000000 0.00000000 1.280169
# [58,] 0.0000000 0.00000000 1.280169
# [59,] 0.0000000 0.00000000 1.280169
# [60,] 0.0000000 0.00000000 1.280169
# [61,] 0.0000000 0.00000000 1.280169
# [62,] 0.0000000 0.00000000 1.280169
# [63,] 0.0000000 0.00000000 1.280169
# [64,] 0.0000000 0.00000000 1.280169
# [65,] 0.0000000 0.00000000 1.280169
# [66,] 0.0000000 0.00000000 1.280169
# [67,] 0.3333333 0.01709776 1.887828
# [68,] 0.3333333 0.01709776 1.887828
# [69,] 0.3333333 0.01709776 1.887828
# [70,] 0.6666667 0.18282773 2.430344
# [71,] 0.6666667 0.18282773 2.430344
# [72,] 0.6666667 0.18282773 2.430344
# [73,] 0.3333333 0.01709776 1.887828
# [74,] 0.3333333 0.01709776 1.887828
# [75,] 0.3333333 0.01709776 1.887828
# [76,] 0.3333333 0.01709776 1.887828
# [77,] 0.0000000 0.00000000 1.280169
# [78,] 0.3333333 0.01709776 1.887828
# [79,] 0.3333333 0.01709776 1.887828
# [80,] 0.3333333 0.01709776 1.887828
# [81,] 0.3333333 0.01709776 1.887828
# [82,] 0.3333333 0.01709776 1.887828
# [83,] 0.6666667 0.18282773 2.430344
# [84,] 0.3333333 0.01709776 1.887828
# [85,] 1.0000000 0.34010127 2.939572
# [86,] 1.0000000 0.34010127 2.939572
# [87,] 1.0000000 0.34010127 2.939572
# [88,] 1.0000000 0.34010127 2.939572
# [89,] 0.6666667 0.18282773 2.430344
# [90,] 0.6666667 0.18282773 2.430344
# [91,] 0.0000000 0.00000000 1.280169
# [92,] 0.0000000 0.00000000 1.280169
# [93,] 0.0000000 0.00000000 1.280169
# [94,] 0.0000000 0.00000000 1.280169
# [95,] 0.3333333 0.01709776 1.887828
# [96,] 0.3333333 0.01709776 1.887828
# [97,] 0.3333333 0.01709776 1.887828
# [98,] 0.6666667 0.18282773 2.430344

# %%
#
cols = rainbow(length(genes), v = 0.8); names(cols) = genes

p = function() {
    par(mfrow = c(2,3), par(mar = c(3,3,3,0.5)))
    for (gene in genes) {
        plot(eyes, eyes, type = "n", axes = F, xlab = "", ylab = "", ylim = c(0,max(m[[gene]], na.rm=T)), main = gene)
        axis(1); axis(2, las = 2)
        coords = cbind(x = c(eyes, rev(eyes)), y = c(m[[gene]][,2], rev(m[[gene]][,3])))
        polygon(coords, col = alpha(cols[gene], 0.1), border = cols[gene])
        lines(eyes, m[[gene]][,1], col = cols[gene], lwd = 3)    
    }

}

p()
pdf(paste0(outdir, "/FigS4k.pdf"), height=4, width = 6)
p()
dev.off()
#plot(score4[ cells], primary_n[gene, cells])
# Out:
# png
#   2
# Plot with title “VIPR1-AS1”

# %%
l = c('Colon@adult@CD117+', 'Ileum@adult@CD117+')

# %%
cells = names(comb)[ comb %in% l]
plot(score4[cells],score3[cells])
cor.test(score4[cells],score3[cells], m = "spearman")
abline(h=17)
# Out:
# Warning message in cor.test.default(score4[cells], score3[cells], m = "spearman"):
# “Cannot compute exact p-value with ties”
# 	Spearman's rank correlation rho
#
# data:  score4[cells] and score3[cells]
# S = 28663570, p-value = 0.00204
# alternative hypothesis: true rho is not equal to 0
# sample estimates:
#       rho
# 0.1276036
# plot without title

# %%
#cc_fac = paste0(comb[ifelse(score3[cells] > 20, "Yes", "No"); names(cc_fac) = cells
cc_fac = factor(comb2[ cells], levels = paste0(rep(l, each = 3), "@", rep(c("None", "Tuft-3", NA), 2)))
names(cc_fac) = cells
table(cc_fac)
# Out:
# cc_fac
#   Colon@adult@CD117+@None Colon@adult@CD117+@Tuft-3     Colon@adult@CD117+@NA
#                       246                        25                         0
#   Ileum@adult@CD117+@None Ileum@adult@CD117+@Tuft-3     Ileum@adult@CD117+@NA
#                       295                        16                         0

# %%
p = function() {
    boxplot(score4[cells] ~ cc_fac[ cells], axes = F, col = c("gray80", cc_col, NA), xlab = "", ylab = "Tuft-4 score")
    axis(2, las = 2); axis(1, at = c(1.5, 4.5), labels = c("Colon", "Ileum"));
}

wilcox.test(score4[ names(cc_fac)[cc_fac == "Ileum@adult@CD117+@None"]], score4[ names(cc_fac)[cc_fac == "Ileum@adult@CD117+@Tuft-3"]])
wilcox.test(score4[ names(cc_fac)[cc_fac == "Colon@adult@CD117+@None"]], score4[ names(cc_fac)[cc_fac == "Colon@adult@CD117+@Tuft-3"]])

p()
pdf(paste0(outdir, "/FigS4l.pdf"), useDingbats = F)
p()
dev.off()
# Out:
# 	Wilcoxon rank sum test with continuity correction
#
# data:  score4[names(cc_fac)[cc_fac == "Ileum@adult@CD117+@None"]] and score4[names(cc_fac)[cc_fac == "Ileum@adult@CD117+@Tuft-3"]]
# W = 946, p-value = 5.461e-05
# alternative hypothesis: true location shift is not equal to 0
# 	Wilcoxon rank sum test with continuity correction
#
# data:  score4[names(cc_fac)[cc_fac == "Colon@adult@CD117+@None"]] and score4[names(cc_fac)[cc_fac == "Colon@adult@CD117+@Tuft-3"]]
# W = 2263, p-value = 0.02974
# alternative hypothesis: true location shift is not equal to 0
# png
#   2
# plot without title

# %% [markdown]
# ## Core score over primary

# %%
scdb_init("saved_work", force=T)
sc_mat = scdb_mat("intestinal_tufts_tissue")
sc_mat@ncells
# Out:
# initializing scdb to saved_work
# [1] 688

# %%
cell_stats = sc_mat@cell_metadata[ sc_mat@cells,]
head(cell_stats)
# Out:
#                      amp_batch_id batch_set_id batch_seq_id cell_barcode
# HUB.JO.s054_AAACAGGC HUB.JO.s054  HUB.JO.s054  HUB.JO.s054  AAACAGGC
# HUB.JO.s054_AAAGCGGA HUB.JO.s054  HUB.JO.s054  HUB.JO.s054  AAAGCGGA
# HUB.JO.s054_AAAGGCTG HUB.JO.s054  HUB.JO.s054  HUB.JO.s054  AAAGGCTG
# HUB.JO.s054_AACACGCA HUB.JO.s054  HUB.JO.s054  HUB.JO.s054  AACACGCA
# HUB.JO.s054_AACCCAAC HUB.JO.s054  HUB.JO.s054  HUB.JO.s054  AACCCAAC
# HUB.JO.s054_AACGAGGT HUB.JO.s054  HUB.JO.s054  HUB.JO.s054  AACGAGGT
#                      umicount mt_count coord id              idx source type
# HUB.JO.s054_AAACAGGC 10779    1382     H18   H18@HUB.JO.s054 7   Colon  tissue
# HUB.JO.s054_AAAGCGGA  3161     645     P12   P12@HUB.JO.s054 7   Colon  tissue
# HUB.JO.s054_AAAGGCTG  5351     505     O10   O10@HUB.JO.s054 7   Colon  tissue
# HUB.JO.s054_AACACGCA  6509     912     L20   L20@HUB.JO.s054 7   Colon  tissue
# HUB.JO.s054_AACCCAAC  6845    1147     O15   O15@HUB.JO.s054 7   Colon  tissue
# HUB.JO.s054_AACGAGGT  2258     324     B9    B9@HUB.JO.s054  7   Colon  tissue
#                      gating treatment clover
# HUB.JO.s054_AAACAGGC CD117+ none      different patient
# HUB.JO.s054_AAAGCGGA CD117+ none      different patient
# HUB.JO.s054_AAAGGCTG CD117+ none      different patient
# HUB.JO.s054_AACACGCA CD117+ none      different patient
# HUB.JO.s054_AACCCAAC CD117+ none      different patient
# HUB.JO.s054_AACGAGGT CD117+ none      different patient

# %%
table(cell_stats$source, paste0(cell_stats$type, "@", cell_stats$gating))
quantile(cell_stats$umicount)
# Out:
#
#         tissue@CD117+ tissue@EPCAM+
#   Colon           271             0
#   Ileum           311           106
#        0%       25%       50%       75%      100%
#    501.00   1520.25   2907.50   6686.75 384278.00

# %%
colon_cells = rownames(cell_stats)[ cell_stats$gating == "CD117+"]
length(colon_cells)

colon_umis = read_large_umis("intestinal_tufts_tissue", cells = colon_cells)
# Out:
# [1] 582

# %%
X = obj@assays$RNA
data = X[,samp_cells]
data_n = sweep(data,2,colSums(data),"/") * 1000
table(anno[ samp_cells])
# Out:
#  Stem cells          TA  Enterocyte Goblet cell      Paneth         EEC
#         500         500         500         500         500         112
#        Tuft
#         500

# %%
shared = intersect(rownames(colon_umis), rownames(data))
length(shared)

markers = setdiff(intersect(shared, names(scdb_gset("teichman")@gene_set)), c("MALAT1", "B2M"))
length(markers)
# Out:
# [1] 27701
# [1] 242

# %%
shared_umis = as.matrix(cbind(data[shared,], colon_umis[shared,]))
anno_l = names(table(anno[ colnames(data_n)]))
anno_n = as.numeric(factor(anno[ colnames(data_n)])); names(anno_n) = colnames(data_n)
#clusts = proj_sc_on_clusts(shared_umis, colon_cells, colnames(data), anno_n, markers = markers)

# %%
colon_n = sweep(colon_umis, 2, colSums(colon_umis), "/") * 1000
foc = log(1 + 7 * colon_n)

# %%
core_genes = intersect(rownames(shared_umis), rownames(tuft_genes)[ tuft_genes$anno == "Core"])
length(core_genes)
sort(core_genes)
# Out:
# [1] 222
#   [1] "ABCB9"      "ABHD2"      "AC007494.2" "ACSL4"      "ADGRG6"
#   [6] "ALDH1A1"    "ALOX12B"    "ALOX5"      "ALOX5AP"    "ANKRD40"
#  [11] "ANKS4B"     "ANXA1"      "ANXA4"      "AOC1"       "AP005233.2"
#  [16] "APH1B"      "APOBEC1"    "ARHGAP4"    "ARPC5"      "ASCL2"
#  [21] "ATP2B4"     "AVIL"       "AZGP1"      "B3GNT5"     "B4GALNT4"
#  [26] "BCAM"       "BIK"        "BMX"        "BUB3"       "C11orf53"
#  [31] "C5AR1"      "CACYBP"     "CALM2"      "CAMK2D"     "CBX6"
#  [36] "CC2D1A"     "CCDC115"    "CCSER1"     "CD14"       "CD24"
#  [41] "CDCP1"      "CDS1"       "CEACAM1"    "CEACAM19"   "CLIC5"
#  [46] "CMTM3"      "CNN3"       "COL27A1"    "CORO2B"     "CRYM"
#  [51] "CSK"        "CTDSPL"     "CTSC"       "CTXND1"     "CXXC5"
#  [56] "DCLK2"      "DEPDC1B"    "DPYSL3"     "EIF1B"      "EIF5"
#  [61] "EPG5"       "EPS8L3"     "ESPL1"      "ESPN"       "FAM217B"
#  [66] "FES"        "FURIN"      "FYB1"       "GADD45A"    "GFI1B"
#  [71] "GLRX"       "GMCL1"      "GNAI1"      "GNAI2"      "GNAT3"
#  [76] "GNB3"       "GNG13"      "GPR153"     "GPT2"       "GRK5"
#  [81] "HAP1"       "HCK"        "HEPACAM2"   "HK2"        "HMCES"
#  [86] "HMX3"       "HOTAIRM1"   "HOXA2"      "HOXA3"      "HOXC9"
#  [91] "HPGDS"      "HTR3E"      "IGFBP2"     "IL13RA1"    "IL17RB"
#  [96] "IL19"       "IL27RA"     "IMP4"       "ITFG1"      "KCNN3"
# [101] "KCNQ1"      "KCNQ4"      "KDM4A"      "KIT"        "KLHDC10"
# [106] "KLHDC7A"    "KLK13"      "LACTB2"     "LCK"        "LINC00920"
# [111] "LINC01548"  "LIPG"       "LRMP"       "LRRN2"      "LYPLA1"
# [116] "MAP7"       "MARC1"      "MARCKSL1"   "MATK"       "MEGF9"
# [121] "MICAL2"     "MOB1B"      "MRPS21"     "MTA3"       "MTSS1"
# [126] "MYEOV"      "MYLK"       "MYO15B"     "MYO1B"      "MYZAP"
# [131] "NAB1"       "NCAM1"      "NCK2"       "NCMAP"      "NIN"
# [136] "NMU"        "NRCAM"      "NRTN"       "NXPH4"      "OGDHL"
# [141] "ORMDL1"     "PANK3"      "PAQR5"      "PBXIP1"     "PDLIM5"
# [146] "PEAK1"      "PHF20L1"    "PHLDA1"     "PIK3C2B"    "PIK3CG"
# [151] "PIR"        "PLAC8"      "PLCB2"      "PLCG2"      "PLEKHG7"
# [156] "POU2F1"     "POU2F3"     "PPARGC1B"   "PRAME"      "PRKAR2B"
# [161] "PROX1"      "PRSS3"      "PSTPIP2"    "PTGS1"      "PTPN18"
# [166] "PTPN6"      "PTPRE"      "PTPRJ"      "PVR"        "PYGL"
# [171] "RASGRF2"    "RASSF6"     "RBM38"      "REEP5"      "RNF14"
# [176] "RNF186"     "RNF24"      "RNF5"       "RTN4"       "RUNX1"
# [181] "RUNX2"      "SEC14L1"    "SH2D6"      "SH2D7"      "SKAP2"
# [186] "SLC1A4"     "SLCO3A1"    "SNRNP27"    "SNX9"       "SOX13"
# [191] "SPIB"       "SPTLC2"     "SPTSSB"     "ST18"       "STAT6"
# [196] "STK38"      "TCEA1"      "TCF7"       "TET2"       "TLCD2"
# [201] "TLE4"       "TMEM131L"   "TMEM170A"   "TMEM176A"   "TMEM176B"
# [206] "TMEM198"    "TMEM255B"   "TMEM45B"    "TMEM74B"    "TPD52L1"
# [211] "TREH"       "TRPM5"      "TUBA1A"     "TUBG2"      "UNC5B"
# [216] "UTRN"       "VAV1"       "VRTN"       "VWA1"       "ZFHX3"
# [221] "ZNF280B"    "ZNF664"

# %%
cell_anno = factor(ifelse(colnames(shared_umis) %in% colon_cells, cell_stats[ colnames(shared_umis), "source"], anno_l[anno[ colnames(shared_umis)]]),
                   levels = c(anno_l, "Ileum", "Colon"))
names(cell_anno) = colnames(shared_umis)
table(cell_anno)
# Out:
# cell_anno
#  Stem cells          TA  Enterocyte Goblet cell      Paneth         EEC
#         500         500         500         500         500         112
#        Tuft       Ileum       Colon
#         500         311         271

# %%
shared_n = sweep(shared_umis, 2, colSums(shared_umis), "/") * 1000
foc = log(1 + 7 * shared_n)

# %%
score = colSums(foc[ core_genes,])
boxplot(score ~ cell_anno)
# Out:
# plot without title

# %%
#venn(names(score), colnames(data))
venn(names(anno), colnames(data))
#length(x)

table(anno[ colnames(data)] != "Tuft")

X = outer(score[colnames(data)], x, ">=")
sum(is.na(X))

Y = anno[ colnames(data)] != "Tuft"
sum(is.na(Y))

head(Y[is.na(Y)])
# Out:
#      A    A,B
# 139001   3112
# FALSE  TRUE
#   500  2612
# [1] 0
# [1] 0
# logical(0)

# %%
x = seq(0, max(score), by = 0.25)

#sub_cells = intersect(names(which(!is.na(anno))), colnames(data))
fp = colSums(outer(score[colnames(data)], x, ">=") * (anno[ colnames(data)] != "Tuft") + 
    outer(score[colnames(data)], x, "<") * (anno[ colnames(data)] == "Tuft"))
plot(x, fp, type = "l")

min(fp, na.rm = T)
thresh = x[ which.min(fp)]
thresh

#fp = (score[colnames(data)] >= x & anno[ colnames(data)] < 7) | 
#    (score[colnames(data)] < x & anno[ colnames(data)] == 7)
# Out:
# [1] 25
# [1] 55
# plot without title

# %%
X = table(cell_anno, score > thresh)
Xn = X / rowSums(X)
round(100 * Xn, 1)

barplot(Xn[,2])
# Out:
#
# cell_anno     FALSE  TRUE
#   Stem cells   99.4   0.6
#   TA          100.0   0.0
#   Enterocyte   99.6   0.4
#   Goblet cell  99.8   0.2
#   Paneth       99.8   0.2
#   EEC          98.2   1.8
#   Tuft          3.2  96.8
#   Ileum         3.2  96.8
#   Colon         1.8  98.2
# plot without title

# %%
sub_cells = intersect(names(which(!is.na(cell_anno))), colnames(shared_umis))

p = function() {
    par(mar = c(10,3,1,1))
    plot_density_points(log2(score[sub_cells]), cell_anno[sub_cells], with_box = F, las = 2, grid = F, with_points = F, 
                        pol.col = c(rep("gray80", 6), "antiquewhite", rep("tomato2", 2))) #,
                       #inflate=0.6); 
    abline(h=log2(thresh), lwd = 2)
}

p()
pdf(paste0(outdir, "/Fig2h.pdf"), useDingbats = F)
p()
dev.off()
# Out:
# png
#   2
# plot without title

# %% [markdown]
# ## Fetal

# %% [markdown]
# good_pops = c("Stem cells", "TA", "Enterocyte", "Goblet cell", "Paneth", "EEC", "Tuft")
# anno = factor(anno, levels = good_pops); names(anno) = rownames(metadata)
# table(anno)

# %%
eec_pops = names(table(metadata$annotation))[12:21]
anno = as.vector(metadata$annotation)
names(anno) = rownames(metadata)
anno[ anno %in% eec_pops] = "EEC"
table(metadata$annotation,anno)

# %%
head(metadata)
table(metadata$Age_group, metadata$Diagnosis)

# %%
good_cells = names(anno)[ anno == "Tuft" &
                        metadata$Age_group %in% c("Adult", "First trim", "Second trim", "Pediatric")]
age = as.vector(metadata$Age_group); names(age) = rownames(metadata)
x = table(age[ good_cells])
sort(x)
setdiff(good_pops, names(x))

# %%
good_pops = names(which(x > 30))
anno = factor(age, levels = c("Second trim", "Pediatric", "Adult")); names(anno) = rownames(metadata)
table(anno[ good_cells])

# %% [markdown]
# tuft_cells = intersect(good_cells, names(anno)[ anno == "Tuft"])
# length(tuft_cells)
#
# sort(table(as.vector(metadata[ tuft_cells, "Sample.name"])))

# %%
k=500
samp_cells = good_cells #unlist(tapply(good_cells, anno[good_cells], function(x) sample(x, min(length(x), k))))
table(anno[ samp_cells])
length(samp_cells)
                           
head(samp_cells)

# %%
X = obj@assays$RNA
data = X[,samp_cells]
data_n = sweep(data,2,colSums(data),"/") * 1000

# %%
table(as.vector(metadata[samp_cells, "Sample.name"]), as.vector(metadata[samp_cells, "Age_group"]))

# %% [markdown]
# scdb_add_mat("teichman_all_tuft", scm_new_matrix(X[,samp_cells], cell_metadata = metadata[samp_cells,]) )

# %%
head(metadata)
table(metadata$Diagnosis)
adult_cells = rownames(metadata)[ metadata$Diagnosis == "Healthy adult"]
length(adult_cells)

# %% [markdown]
# scdb_add_mat("teichman_all", scm_new_matrix(X[,adult_cells], cell_metadata = metadata[adult_cells,]))

# %%
anno_l = names(table(anno))
anno_l

# %%
scdb_init("saved_work", force=T)

sc_mat = scdb_mat("all_lulu")
sc_mat@ncells

cell_stats = sc_mat@cell_metadata
head(cell_stats)

# %%
table(cell_stats$type, cell_stats$age)

# %%
table(cell_stats$type, cell_stats$age)

fetal_cells = rownames(cell_stats)[ cell_stats$age == "fetal" & cell_stats$type == "tissue" & cell_stats$gating == "CD117+" &
                    cell_stats$umicount > 500 &
                    cell_stats$mt_count / cell_stats$umicount < 0.4]
length(fetal_cells)

# %%
sort(table(cell_stats[ fetal_cells, "amp_batch_id"]))

# %%
fetal_umis = read_large_umis("all_lulu", cells = fetal_cells)

# %%
shared_genes = intersect(rownames(data), rownames(fetal_umis))
shared_umis = cbind(data_n[ shared_genes,], fetal_umis[ shared_genes,])

# %%
anno_l = names(table(anno))
cell_anno = factor(ifelse(colnames(shared_umis) %in% fetal_cells, "KIT", anno_l[anno[ colnames(shared_umis)]]),
                   levels = c(anno_l, "KIT"))

#cell_anno = anno[ colnames(shared_umis)]
names(cell_anno) = colnames(shared_umis)
table(cell_anno)

# %%
table(cell_anno == "KIT")

# %%
shared_n = sweep(shared_umis, 2, colSums(shared_umis), "/") * 1000
foc = log(1 + 7 * shared_n)

# %%
core_genes = intersect(rownames(shared_umis), rownames(tuft_genes)[ tuft_genes$anno == "Core"])
sort(core_genes)

# %%
score = colSums(foc[ core_genes,])
boxplot(score ~ cell_anno)

# %%
head(anno)

# %%
table(anno[ colnames(data)])

# %%
x = seq(0, max(score), by = 0.25)

sub_cells = intersect(colnames(data), names(which(!is.na(anno))))
fp = colSums(outer(score[sub_cells], x, ">=") * (anno[ sub_cells] != "Tuft") + 
    outer(score[sub_cells], x, "<") * (anno[ sub_cells] == "Tuft"))
plot(x, fp, type = "l")

min(fp)
thresh = x[ which.min(fp)]
thresh

#fp = (score[colnames(data)] >= x & anno[ colnames(data)] < 7) | 
#    (score[colnames(data)] < x & anno[ colnames(data)] == 7)

# %%
X = table(cell_anno, score > thresh)
Xn = X / rowSums(X)
round(100 * Xn, 1)

barplot(Xn[,2])

# %%
p = function() {
    par(mar = c(10,3,1,1))
    plot_density_points(log2(score), cell_anno, with_box = F, las = 2, grid = F, with_points = F, 
        pol.col = c(rep("antiquewhite", 3), "tomato2")) #,

}

p()
pdf(paste0(outdir, "/FigS9b.pdf"), useDingbats = F)
p()
dev.off()

# %%
table(cell_anno)

# %%
genes = c("ALOX5AP", "BMX", "AVIL", "IL13RA1", "KIT", "POU2F3")
m = t(apply(shared_n[genes, ], 1, tapply, cell_anno, mean))
IM = log2(m[, rev(colnames(m))] + 0.02)
exp_freq = t(apply(shared_umis[genes, ] > 0, 1, tapply, cell_anno, mean)) * 100
exp_freq = exp_freq[ ,colnames(IM)]

grad = colorRampPalette(c("white", brewer.pal(9, "YlOrBr")))(101)

p = function() {
    par(mar = c(3,10,1,3))
    matplot.2(t(IM), t(exp_freq), grad=grad, cex_lim = seq(0,100, by = 25))
}

p()
pdf(paste0(outdir, "/FigS9c.pdf"), height=10, width=15, useDingbats = F)
p()
dev.off()

genes = union(read.table("annotations//stem_genes.txt", stringsAsFactors = F)[[1]],
              c("MEX3A", "ANXA1", "TACSTD2", "PROX1"))

m = t(apply(shared_n[genes, ], 1, tapply, cell_anno, mean))
IM = log2(m + 0.02)
exp_freq = t(apply(shared_umis[genes, ] > 0, 1, tapply, cell_anno, mean)) * 100
exp_freq = exp_freq[ ,colnames(m)]

p()
pdf(paste0(outdir, "/FigS9d.pdf"), height=10, width=15, useDingbats = F)
p()
dev.off()
